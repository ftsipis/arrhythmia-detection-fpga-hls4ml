# %% [markdown]
# # Detecting arrythmia using Deep Leaning

# %% [markdown]
# ## Loading modules

# %%
import pandas as pd
import numpy as np
import wfdb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, TimeDistributed
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Download Dataset

# %%
from pathlib import Path
import zipfile

database_filename = "mit-bih-arrhythmia-database-1.0.0.zip"
expected_file = Path("mit-bih-arrhythmia-database-1.0.0")

if not expected_file.exists():
    with zipfile.ZipFile(database_filename, 'r') as zip_ref:
        zip_ref.extractall(".")
    print("Extraction complete.")
else:
    print("Files already extracted.")
# Out:
# Files already extracted.

# %% [markdown]
# ## Loading data

# %% [markdown]
# Loading list of records available, from dataset available [here](https://physionet.org/content/mitdb/1.0.0/)

# %%
records = np.loadtxt("mit-bih-arrhythmia-database-1.0.0/RECORDS", dtype=int)

# %% [markdown]
# Defining invalid beats as well as abnormal beats, according to [Physiobank](https://archive.physionet.org/physiobank/annotations.shtml)

# %%
invalid_beat = [
    "[", "!", "]", "x", "(", ")", "p", "t", 
    "u", "`", "'", "^", "|", "~", "+", "s", 
    "T", "*", "D", "=", '"', "@"
]

abnormal_beats = [
    "L", "R", "B", "A", "a", "J", "S", "V", 
    "r", "F", "e", "j", "n", "E", "/", "f", "Q", "?"
]

# %% [markdown]
# ## Processing dataset

# %% [markdown]
# This function classify a beat according to its symbol and the list provided above.

# %%
def classify_beat(symbol):
    if symbol in abnormal_beats:
        return 1
    elif symbol == "N" or symbol == ".":
        return 0

# %% [markdown]
# Given a signal, the beat location, and the window to be used as a sequence, this function gets the sequence. It will return an empty array in case of an invalid beat or empty sequence.

# %%
def get_sequence(signal, beat_loc, window_sec, fs):
    window_one_side = window_sec * fs
    beat_start = beat_loc - window_one_side
    beat_end = beat_loc + window_one_side
    if beat_end < signal.shape[0]:
        sequence = signal[beat_start:beat_end, 0]
        return sequence.reshape(1, -1, 1)
    else:
        return np.array([])

# %% [markdown]
# The code below will build a list of labels and sequences as well as map the sequences for each patient. The percentage calculated represents the ratio of abnormal beats in each patient data.

# %%
all_sequences = []
all_labels = []
window_sec = 3
subject_map = []
for subject in records:
    record = wfdb.rdrecord(f'mit-bih-arrhythmia-database-1.0.0/{subject}')
    annotation = wfdb.rdann(f'mit-bih-arrhythmia-database-1.0.0/{subject}', 'atr')
    atr_symbol = annotation.symbol
    atr_sample = annotation.sample
    fs = record.fs
    scaler = StandardScaler()
    signal = scaler.fit_transform(record.p_signal)
    subject_labels = []
    for i, i_sample in enumerate(atr_sample):
        label = classify_beat(atr_symbol[i])
        sequence = get_sequence(signal, i_sample, window_sec, fs)
        if label is not None and sequence.size > 0:
            all_sequences.append(sequence)
            subject_labels.append(label)

    normal_percentage = sum(subject_labels) / len(subject_labels)
    subject_map.append({
        "subject": subject,
        "percentage": normal_percentage,
        "num_seq": len(subject_labels),
        "start": len(all_labels),
        "end": len(all_labels)+len(subject_labels)
    })
    all_labels.extend(subject_labels)

# %%
print(subject_map[:5])
# Out:
# [{'subject': 100, 'percentage': 0.014997794441993825, 'num_seq': 2267, 'start': 0, 'end': 2267}, {'subject': 101, 'percentage': 0.002688172043010753, 'num_seq': 1860, 'start': 2267, 'end': 4127}, {'subject': 102, 'percentage': 0.9546287809349221, 'num_seq': 2182, 'start': 4127, 'end': 6309}, {'subject': 103, 'percentage': 0.0009615384615384616, 'num_seq': 2080, 'start': 6309, 'end': 8389}, {'subject': 104, 'percentage': 0.9266756635177688, 'num_seq': 2223, 'start': 8389, 'end': 10612}]

# %% [markdown]
# Creating bins to be used to stratify the train and validation split.

# %%
subject_map = pd.DataFrame(subject_map)

# %%
print(subject_map[:5])
# Out:
#    subject  percentage  num_seq  start    end
# 0      100    0.014998     2267      0   2267
# 1      101    0.002688     1860   2267   4127
# 2      102    0.954629     2182   4127   6309
# 3      103    0.000962     2080   6309   8389
# 4      104    0.926676     2223   8389  10612

# %% [markdown]
# The code presented will create class in each patient is segmented.

# %%
bins = [0, 0.2, 0.6, 1.0]
subject_map["bin"] = pd.cut(subject_map['percentage'], bins=bins, labels=False, include_lowest=True)

# %%
print(subject_map[:5])
# Out:
#    subject  percentage  num_seq  start    end  bin
# 0      100    0.014998     2267      0   2267    0
# 1      101    0.002688     1860   2267   4127    0
# 2      102    0.954629     2182   4127   6309    2
# 3      103    0.000962     2080   6309   8389    0
# 4      104    0.926676     2223   8389  10612    2

# %% [markdown]
# Now, the dataset is split into train and validation, stratifying by the bin defined above.

# %%
train, validation = train_test_split(subject_map, test_size=0.25, stratify=subject_map["bin"], random_state=42)

# %% [markdown]
# This function build a dataset based on the map for each split.

# %%
def build_dataset(df, all_sequences, all_labels):
    sequences = []
    labels = []
    for i, row in df.iterrows():
        start = int(row["start"])
        end = int(row["end"])
        sequences.extend(all_sequences[start:end])
        labels.extend(all_labels[start:end])
        
    return np.vstack(sequences), np.vstack(labels)

# %%
X_train, y_train = build_dataset(train, all_sequences, all_labels)
X_val, y_val = build_dataset(validation, all_sequences, all_labels)

# %%
X_train.shape, y_train.shape
# Out:
# ((82964, 1440, 1), (82964, 1))

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### CNN model

# %%
from tensorflow.keras.layers import Input, Flatten, MaxPooling1D, Dropout
from tensorflow.keras.models import Model
from qkeras import QConv1D, QActivation, QDense
from tensorflow.keras.optimizers import Adam

sequence_size = X_train.shape[1]
n_features = 1

inputs = Input(shape=(sequence_size, n_features))

# Quantized Conv1D
x = QConv1D(
    filters=16,
    kernel_size=4,
    strides=1,
    padding="same",
    kernel_quantizer="quantized_bits(2,0,alpha=1)",
    bias_quantizer="quantized_bits(2,0,alpha=1)",
    name="qconv1d"
)(inputs)
x = QActivation('quantized_relu(2,0)', name="qact_conv")(x)
x = MaxPooling1D(pool_size=4, name="maxpool")(x)
x = Flatten(name="flatten")(x)
x = Dropout(0.5, name="dropout")(x)

# Quantized Dense
x = QDense(
    1,
    kernel_quantizer="quantized_bits(2,0,alpha=1)",
    bias_quantizer="quantized_bits(2,0,alpha=1)",
    name="qdense"
)(x)
outputs = QActivation('quantized_sigmoid(2)', name="qact_output")(x)

cnn_model = Model(inputs=inputs, outputs=outputs, name="quantized_cnn")

optimizer = Adam(learning_rate=0.001)
cnn_model.compile(
    optimizer=optimizer,
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

cnn_model.summary()

# Print the quantized layers
from qkeras.autoqkeras.utils import print_qmodel_summary

print_qmodel_summary(cnn_model)
# Out:
# Model: "quantized_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1440, 1)]         0
#
#  qconv1d (QConv1D)           (None, 1440, 16)          80
#
#  qact_conv (QActivation)     (None, 1440, 16)          0
#
#  maxpool (MaxPooling1D)      (None, 360, 16)           0
#
#  flatten (Flatten)           (None, 5760)              0
#
#  dropout (Dropout)           (None, 5760)              0
#
#  qdense (QDense)             (None, 1)                 5761
#
#  qact_output (QActivation)   (None, 1)                 0
#
# =================================================================
# Total params: 5841 (22.82 KB)
# Trainable params: 5841 (22.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# qconv1d              f=16 quantized_bits(2,0,0,alpha=1) quantized_bits(2,0,0,alpha=1)
# qact_conv            quantized_relu(2,0)
# qdense               u=1 quantized_bits(2,0,0,alpha=1) quantized_bits(2,0,0,alpha=1)
# qact_output          quantized_sigmoid(2)
# /home/fotis/anaconda3/envs/arrhythmia/lib/python3.10/site-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(

# %%
import json
from tensorflow.keras.models import load_model

train = True
if train:
    hist_cnn = cnn_model.fit(
        X_train, 
        y_train, 
        batch_size=128,
        epochs=15,
        validation_data=(X_val, y_val)
    )
    cnn_model.save('QKeras_Model4_2bits/cnn_model.keras')

    with open('QKeras_Model4_2bits/hist_cnn.json', 'w') as f:
        json.dump(hist_cnn.history, f)

    with open('QKeras_Model4_2bits/hist_cnn.json', 'r') as f:
        hist_cnn = json.load(f)
else:
    cnn_model = load_model('QKeras_Model4_2bits/cnn_model.keras')

    with open('QKeras_Model4_2bits/hist_cnn.json', 'r') as f:
        hist_cnn = json.load(f)
# Out:
# Epoch 1/15
# 649/649 [==============================] - 12s 18ms/step - loss: 3.7197 - accuracy: 0.7207 - val_loss: 3.0778 - val_accuracy: 0.7627
# Epoch 2/15
# 649/649 [==============================] - 13s 20ms/step - loss: 1.7427 - accuracy: 0.8340 - val_loss: 2.4443 - val_accuracy: 0.7626
# Epoch 3/15
# 649/649 [==============================] - 14s 21ms/step - loss: 1.1616 - accuracy: 0.8793 - val_loss: 1.9220 - val_accuracy: 0.7222
# Epoch 4/15
# 649/649 [==============================] - 13s 19ms/step - loss: 0.9556 - accuracy: 0.8931 - val_loss: 1.9755 - val_accuracy: 0.7654
# Epoch 5/15
# 649/649 [==============================] - 12s 18ms/step - loss: 0.9889 - accuracy: 0.8969 - val_loss: 2.2063 - val_accuracy: 0.7457
# Epoch 6/15
# 649/649 [==============================] - 11s 17ms/step - loss: 0.9007 - accuracy: 0.9056 - val_loss: 2.2383 - val_accuracy: 0.7800
# Epoch 7/15
# 649/649 [==============================] - 12s 18ms/step - loss: 0.8590 - accuracy: 0.9089 - val_loss: 1.8943 - val_accuracy: 0.7851
# Epoch 8/15
# 649/649 [==============================] - 12s 18ms/step - loss: 0.8541 - accuracy: 0.9097 - val_loss: 1.9066 - val_accuracy: 0.8083
# Epoch 9/15
# 649/649 [==============================] - 12s 19ms/step - loss: 0.8611 - accuracy: 0.9116 - val_loss: 2.0259 - val_accuracy: 0.7908
# Epoch 10/15
# 649/649 [==============================] - 12s 18ms/step - loss: 0.8117 - accuracy: 0.9131 - val_loss: 1.9977 - val_accuracy: 0.7783
# Epoch 11/15
# 649/649 [==============================] - 12s 18ms/step - loss: 0.8405 - accuracy: 0.9103 - val_loss: 2.2525 - val_accuracy: 0.7860
# Epoch 12/15
# 649/649 [==============================] - 12s 19ms/step - loss: 0.8595 - accuracy: 0.9115 - val_loss: 2.2468 - val_accuracy: 0.7743
# Epoch 13/15
# 649/649 [==============================] - 11s 18ms/step - loss: 0.8032 - accuracy: 0.9141 - val_loss: 1.9504 - val_accuracy: 0.7812
# Epoch 14/15
# 649/649 [==============================] - 11s 17ms/step - loss: 0.8046 - accuracy: 0.9157 - val_loss: 2.4279 - val_accuracy: 0.7841
# Epoch 15/15
# 649/649 [==============================] - 11s 17ms/step - loss: 0.8352 - accuracy: 0.9153 - val_loss: 2.0297 - val_accuracy: 0.7863
# /home/fotis/anaconda3/envs/arrhythmia/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(

# %%
cnn_model.evaluate(X_val, y_val)
# Out:
# 822/822 [==============================] - 2s 2ms/step - loss: 2.0297 - accuracy: 0.7863
# [2.029651165008545, 0.7863121032714844]

# %%
# summarize history for accuracy
plt.plot(hist_cnn['accuracy'])
plt.plot(hist_cnn['val_accuracy'])
plt.title('CNN model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist_cnn['loss'])
plt.plot(hist_cnn['val_loss'])
plt.title('CNN model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Make an hls4ml config & model

# %%
import hls4ml
import plotting 

os.environ['PATH'] = os.environ['XILINX_VITIS'] + '/bin:' + os.environ['PATH']

config = hls4ml.utils.config_from_keras_model(cnn_model, granularity='name', backend='Vitis')
config['Model']['ReuseFactor'] = 1
config['Model']['Precision'] = 'ap_fixed<16,6>'
print("-----------------------------------")
print("Configuration")
plotting.print_dict(config)
print("-----------------------------------")
hls_model = hls4ml.converters.convert_from_keras_model(cnn_model, hls_config=config, backend='Vitis', output_dir='hls4ml/QKeras_model_4_2bits', part='xcu250-figd2104-2L-e', io_type='io_stream')
# Out:
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 1440, 1]], output shape: [None, 1440, 1]
# Layer name: qconv1d, layer type: QConv1D, input shapes: [[None, 1440, 1]], output shape: [None, 1440, 16]
# Layer name: qact_conv, layer type: Activation, input shapes: [[None, 1440, 16]], output shape: [None, 1440, 16]
# Layer name: maxpool, layer type: MaxPooling1D, input shapes: [[None, 1440, 16]], output shape: [None, 360, 16]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 360, 16]], output shape: [None, 5760]
# Layer name: qdense, layer type: QDense, input shapes: [[None, 5760]], output shape: [None, 1]
# Layer name: qact_output, layer type: HardActivation, input shapes: [[None, 1]], output shape: [None, 1]
# -----------------------------------
# Configuration
# Model
#   Precision:         ap_fixed<16,6>
#   ReuseFactor:       1
#   Strategy:          Latency
#   BramFactor:        1000000000
#   TraceOutput:       False
# LayerName
#   input_1
#     Trace:           False
#     Precision
#       result:        auto
#   qconv1d
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        fixed<2,1,TRN,WRAP,0>
#       bias:          fixed<2,1,TRN,WRAP,0>
#       accum:         auto
#     ReuseFactor:     1
#     ParallelizationFactor:1
#     ConvImplementation:LineBuffer
#   qconv1d_linear
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   qact_conv
#     Trace:           False
#     Precision
#       result:        ufixed<2,0,RND_CONV,SAT,0>
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   maxpool
#     Trace:           False
#     Precision
#       result:        auto
#       accum:         auto
#     ReuseFactor:     1
#     ConvImplementation:LineBuffer
#   flatten
#     Trace:           False
#     Precision
#       result:        auto
#   qdense
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        fixed<2,1,TRN,WRAP,0>
#       bias:          fixed<2,1,TRN,WRAP,0>
#       accum:         auto
#     ReuseFactor:     1
#   qdense_linear
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   qact_output
#     Trace:           False
#     Precision
#       result:        ufixed<2,0,RND_CONV,SAT,0>
#       slope:         auto
#       shift:         auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
# -----------------------------------
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 1440, 1]], output shape: [None, 1440, 1]
# Layer name: qconv1d, layer type: QConv1D, input shapes: [[None, 1440, 1]], output shape: [None, 1440, 16]
# Layer name: qact_conv, layer type: Activation, input shapes: [[None, 1440, 16]], output shape: [None, 1440, 16]
# Layer name: maxpool, layer type: MaxPooling1D, input shapes: [[None, 1440, 16]], output shape: [None, 360, 16]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 360, 16]], output shape: [None, 5760]
# Layer name: qdense, layer type: QDense, input shapes: [[None, 5760]], output shape: [None, 1]
# Layer name: qact_output, layer type: HardActivation, input shapes: [[None, 1]], output shape: [None, 1]
# Creating HLS model
# /home/fotis/anaconda3/envs/arrhythmia/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(

# %% [markdown]
# ## Visualise the model architecture

# %%
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=None)

# %% [markdown]
# ## Compile, predict

# %%
hls_model.compile()
X_val = np.ascontiguousarray(X_val)
y_hls = hls_model.predict(X_val)
# Out:
# /home/fotis/anaconda3/envs/arrhythmia/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(
# Writing HLS project
# Done

# %% [markdown]
# ## HLS4ML Model Accuracy

# %%
from sklearn.metrics import accuracy_score

# Convert predictions to binary labels using a threshold of 0.5
y_hls_pred   = (y_hls > 0.5).astype(int)

# Calculate accuracy using ground truth y_val
acc_hls   = accuracy_score(y_val, y_hls_pred)

print("HLS4ML Model Accuracy: {:.2f}%".format(acc_hls * 100))
# Out:
# HLS4ML Model Accuracy: 78.61%

# %% [markdown]
# ## Synthesize

# %%
hls_model.build(csim=False, synth=True, vsynth=True, export=True)
# Out:
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2023.2 (64-bit)
#   **** SW Build 4023990 on Oct 11 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis_HLS/2023.2/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vitis_HLS/2023.2/bin/unwrapped/lnx64.o/vitis_hls'
# INFO: [HLS 200-10] For user 'fotis' on host 'fotis-Z390-UD' (Linux_x86_64 version 6.8.0-64-generic) on Mon Jul 21 15:31:00 EEST 2025
# INFO: [HLS 200-10] On os Ubuntu 24.04.2 LTS
# INFO: [HLS 200-10] In directory '/home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits'
# INFO: [HLS 200-2053] The vitis_hls executable is being deprecated. Consider using vitis-run --mode hls --tcl
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-1510] Running: open_project myproject_prj
# INFO: [HLS 200-10] Creating and opening project '/home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj'.
# INFO: [HLS 200-1510] Running: set_top myproject
# INFO: [HLS 200-1510] Running: add_files firmware/myproject.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb myproject_test.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb firmware/weights
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-1510] Running: add_files -tb tb_data
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-1510] Running: open_solution solution1
# INFO: [HLS 200-10] Creating and opening solution '/home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1510] Running: config_array_partition -maximum_size 4096
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# ERROR: [HLS 200-642] The 'config_array_partition -maximum_size' command is not supported.
# INFO: [HLS 200-1510] Running: config_compile -name_max_length 80
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: set_part xcu250-figd2104-2L-e
# INFO: [HLS 200-1611] Setting target device to 'xcu250-figd2104-2L-e'
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: config_schedule -enable_dsp_full_reg=false
# INFO: [HLS 200-1510] Running: create_clock -period 5 -name default
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [HLS 200-1510] Running: set_clock_uncertainty 27% default
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 1.35ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [HLS 200-1510] Running: csynth_design
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 0.02 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.03 seconds; current allocated memory: 282.184 MB.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:33:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:107:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:189:9)
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:38:82)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:38:86)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:51:74)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:51:78)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 200-471] Dataflow form checks found 4 issue(s) in file firmware/myproject.cpp
# Resolution: For help on HLS 200-471 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-471.html
# WARNING: [HLS 207-5292] unused parameter 'keep' (firmware/nnet_utils/nnet_helpers.h:285:99)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:14:36)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:15:36)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:16:44)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:24:24)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:25:24)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:26:32)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:33:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:33:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:34:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:35:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:42:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:42:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:43:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:44:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:51:29)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:51:80)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:52:50)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:53:48)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:16:39)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_code_gen.h:17:38)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_code_gen.h:18:60)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_code_gen.h:19:58)
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 4.77 seconds. CPU system time: 0.37 seconds. Elapsed time: 5.14 seconds; current allocated memory: 290.574 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# INFO: [HLS 200-1995] There were 4,707 instructions in the design after the 'Compile/Link' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# WARNING: [HLS 200-1995] There were 363,688 instructions in the design after the 'Unroll/Inline' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 94,662 instructions in the design after the 'Unroll/Inline (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 94,564 instructions in the design after the 'Unroll/Inline (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 94,329 instructions in the design after the 'Unroll/Inline (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 80,898 instructions in the design after the 'Array/Struct' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 24,212 instructions in the design after the 'Array/Struct (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 24,224 instructions in the design after the 'Array/Struct (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 24,870 instructions in the design after the 'Array/Struct (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 18,879 instructions in the design after the 'Array/Struct (step 5)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 14,228 instructions in the design after the 'Performance (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 14,216 instructions in the design after the 'Performance (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 14,166 instructions in the design after the 'Performance (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 14,054 instructions in the design after the 'Performance (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 13,943 instructions in the design after the 'HW Transforms (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 14,111 instructions in the design after the 'HW Transforms (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/QKeras_model_4_2bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::pooling1d_cl<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>' (firmware/nnet_utils/nnet_pooling_stream.h:182:9)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>' (firmware/nnet_utils/nnet_dense_stream.h:85:9)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>*, config7::weight_t*, config7::bias_t*)', Pragma conflict happens on 'INLINE' and 'PIPELINE' pragmas: same function (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:33:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_data<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:38:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:43:9)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<2, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<2, 1, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2_mult::weight_t*, config2_mult::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:347:5)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseLatency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>::dense(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<2, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<2, 1, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:354:9)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[](unsigned long) const (.16)' into 'void nnet::kernel_shift_1d<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>(nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u> const&, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::value_type*) (.15)' (firmware/nnet_utils/nnet_conv_stream.h:176:37)
# INFO: [HLS 214-131] Inlining function 'nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> >::operator()(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>) (.12)' into 'ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> nnet::reduce<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 2, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> > >(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> const*, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> >) (.14)' (firmware/nnet_utils/nnet_common.h:44:16)
# INFO: [HLS 214-131] Inlining function 'ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> nnet::reduce<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 2, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> > >(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> const*, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> >) (.14)' into 'ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> nnet::reduce<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> > >(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> const*, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> >) (.11)' (firmware/nnet_utils/nnet_common.h:46:15)
# INFO: [HLS 214-131] Inlining function 'nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> >::operator()(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>) (.12)' into 'ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> nnet::reduce<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> > >(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> const*, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> >) (.11)' (firmware/nnet_utils/nnet_common.h:46:12)
# INFO: [HLS 214-131] Inlining function 'ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> nnet::reduce<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 2, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> > >(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> const*, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> >) (.14)' into 'ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> nnet::reduce<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> > >(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> const*, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> >) (.11)' (firmware/nnet_utils/nnet_common.h:46:44)
# INFO: [HLS 214-131] Inlining function 'ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> nnet::reduce<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> > >(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> const*, nnet::Op_max<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> >) (.11)' into 'ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> nnet::reduce_pool<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4, config5>(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*) (.10)' (firmware/nnet_utils/nnet_pooling_stream.h:21:16)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>(nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u> const&, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::value_type*) (.15)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>(nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u> const&, hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&) (.8)' (firmware/nnet_utils/nnet_pooling_stream.h:142:5)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[](unsigned long) (.5)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>(nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u> const&, hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&) (.8)' (firmware/nnet_utils/nnet_pooling_stream.h:157:13)
# INFO: [HLS 214-131] Inlining function 'ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0> nnet::reduce_pool<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4, config5>(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*) (.10)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>(nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u> const&, hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&) (.8)' (firmware/nnet_utils/nnet_pooling_stream.h:157:30)
# INFO: [HLS 214-131] Inlining function 'void nnet::compute_pool_buffer_1d<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>(nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u> const&, hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&) (.8)' into 'void nnet::pooling1d_cl<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>(hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_pooling_stream.h:187:2)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[](unsigned long) (.5)' into 'void nnet::data_prepare<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config7>(hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::value_type*) (.4)' (firmware/nnet_utils/nnet_dense_stream.h:39:39)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<2, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<2, 1, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>*, config7::weight_t*, config7::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long) (.3)' into 'void nnet::res_write<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*, hls::stream<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&) (.1)' (firmware/nnet_utils/nnet_dense_stream.h:75:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::data_prepare<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config7>(hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::value_type*) (.4)' into 'void nnet::dense<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, config7::weight_t*, config7::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:93:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::res_write<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*, hls::stream<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&) (.1)' into 'void nnet::dense<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, config7::weight_t*, config7::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:100:5)
# INFO: [HLS 214-291] Loop 'HardSigmoidPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:459:9)
# INFO: [HLS 214-291] Loop 'DataPackPipeline' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_stream.h:37:13)
# INFO: [HLS 214-291] Loop 'Result' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:64:5)
# INFO: [HLS 214-291] Loop 'Accum1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:54:5)
# INFO: [HLS 214-291] Loop 'Accum2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:56:9)
# INFO: [HLS 214-291] Loop 'ResetAccum' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:48:5)
# INFO: [HLS 214-291] Loop 'Product1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:37:5)
# INFO: [HLS 214-291] Loop 'Product2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:40:9)
# INFO: [HLS 214-291] Loop 'KernelShiftWidth' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:161:5)
# INFO: [HLS 214-291] Loop 'KernelShiftChannel' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:164:9)
# INFO: [HLS 214-291] Loop 'KernelPushChannel' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:174:5)
# INFO: [HLS 214-291] Loop 'FiltLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_pooling_stream.h:147:9)
# INFO: [HLS 214-291] Loop 'PoolLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_pooling_stream.h:152:13)
# INFO: [HLS 214-291] Loop 'ReLUPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:49:9)
# INFO: [HLS 214-291] Loop 'CastLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:359:9)
# INFO: [HLS 214-186] Unrolling loop 'HardSigmoidPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:459:9) in function 'nnet::hard_sigmoid<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 1u>, hard_sigmoid_config9>' completely with a factor of 1 (firmware/nnet_utils/nnet_activation_stream.h:448:0)
# INFO: [HLS 214-186] Unrolling loop 'ResPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:73:9) in function 'nnet::dense<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'DataPackPipeline' (firmware/nnet_utils/nnet_dense_stream.h:37:13) in function 'nnet::dense<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 5760 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 5760 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::pooling1d_cl<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>' completely with a factor of 3 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# WARNING: [HLS 214-189] Pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::pooling1d_cl<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>' has been removed because the loop is unrolled completely (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:164:9) in function 'nnet::pooling1d_cl<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>' completely with a factor of 16 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelPushChannel' (firmware/nnet_utils/nnet_conv_stream.h:174:5) in function 'nnet::pooling1d_cl<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>' completely with a factor of 16 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'FiltLoop' (firmware/nnet_utils/nnet_pooling_stream.h:147:9) in function 'nnet::pooling1d_cl<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>' completely with a factor of 16 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# WARNING: [HLS 214-189] Pipeline directive for loop 'FiltLoop' (firmware/nnet_utils/nnet_pooling_stream.h:147:9) in function 'nnet::pooling1d_cl<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>' has been removed because the loop is unrolled completely (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'PoolLoop' (firmware/nnet_utils/nnet_pooling_stream.h:152:13) in function 'nnet::pooling1d_cl<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, config5>' completely with a factor of 4 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49:9) in function 'nnet::relu<nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config4>' completely with a factor of 16 (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-186] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:359:9) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' completely with a factor of 16 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelPushChannel' (firmware/nnet_utils/nnet_conv_stream.h:174:5) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' completely with a factor of 1 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' completely with a factor of 3 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# WARNING: [HLS 214-189] Pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' has been removed because the loop is unrolled completely (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:164:9) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' completely with a factor of 1 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 4 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 4 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_22_1' (firmware/nnet_utils/nnet_padding_stream.h:22:22) in function 'nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>' completely with a factor of 1 (firmware/nnet_utils/nnet_padding_stream.h:30:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config10>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:30:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_uint<1> >::value), ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(config2_mult::accum_t)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2_mult::weight_t*, config2_mult::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long) const' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long)' into 'void nnet::relu<nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config4>(hls::stream<nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[](unsigned long)' into 'void nnet::relu<nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config4>(hls::stream<nnet::array<ap_fixed<21, 10, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_uint<1> >::value), ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>(config7::accum_t)' into 'void nnet::dense_latency<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>*, config7::weight_t*, config7::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long)' into 'void nnet::hard_sigmoid<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 1u>, hard_sigmoid_config9>(hls::stream<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:448:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 1u>::operator[](unsigned long)' into 'void nnet::hard_sigmoid<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 1u>, hard_sigmoid_config9>(hls::stream<nnet::array<ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:448:0)
# INFO: [HLS 214-248] Applying array_partition to 'b2': Complete partitioning on dimension 1. (firmware/weights/b2.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to 'b7': Complete partitioning on dimension 1. (firmware/weights/b7.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to '_ZZN4nnet22compute_pool_buffer_1dINS_5arrayI9ap_ufixedILi2ELi0EL9ap_q_mode4EL9ap_o_mode0ELi0EELj16EEES6_7config5EEvRKT_RN3hls6streamIT0_Li0EEEE11kernel_data': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_pooling_stream.h:134:0)
# INFO: [HLS 214-248] Applying array_partition to '_ZZN4nnet24compute_output_buffer_1dINS_5arrayI8ap_fixedILi16ELi6EL9ap_q_mode5EL9ap_o_mode3ELi0EELj1EEENS1_IS2_ILi21ELi10ELS3_5ELS4_3ELi0EELj16EEE7config2EEvRKT_RN3hls6streamIT0_Li0EEEPNT1_8weight_tEPNSI_6bias_tEE11kernel_data': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_conv_stream.h:337:0)
# INFO: [HLS 214-248] Applying array_partition to 'res_out': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_conv_stream.h:340:29)
# INFO: [HLS 214-248] Applying array_partition to 'mult': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_latency.h:17:32)
# INFO: [HLS 214-248] Applying array_partition to 'data': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_stream.h:87:30)
# INFO: [HLS 214-248] Applying array_partition to 'res': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_stream.h:90:29)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer7_out' with compact=bit mode in 18-bits (firmware/myproject.cpp:49:34)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer5_out' with compact=bit mode in 32-bits (firmware/myproject.cpp:44:27)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer4_out' with compact=bit mode in 32-bits (firmware/myproject.cpp:40:27)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer2_out' with compact=bit mode in 336-bits (firmware/myproject.cpp:36:35)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer10_out' with compact=bit mode in 16-bits (firmware/myproject.cpp:32:25)
# INFO: [HLS 214-364] Automatically inlining function 'void nnet::dense_latency<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>*, config7::weight_t*, config7::bias_t*)' to improve effectiveness of pipeline pragma in function 'void nnet::dense_latency_wrapper<ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config7>(ap_ufixed<2, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<18, 15, (ap_q_mode)5, (ap_o_mode)3, 0>*, config7::weight_t*, config7::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:17:2)
# INFO: [HLS 214-376] automatically set the pipeline for Loop< CopyMain> at firmware/nnet_utils/nnet_padding_stream.h:37:5
# INFO: [HLS 214-376] automatically set the pipeline for Loop< PadRight> at firmware/nnet_utils/nnet_padding_stream.h:42:5
# INFO: [HLS 200-111] Finished Compiling Optimization and Transform: CPU user time: 167.68 seconds. CPU system time: 1.27 seconds. Elapsed time: 170.47 seconds; current allocated memory: 439.055 MB.
# INFO: [HLS 200-111] Finished Checking Pragmas: CPU user time: 0 seconds. CPU system time: 0 seconds. Elapsed time: 0 seconds; current allocated memory: 439.055 MB.
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-111] Finished Standard Transforms: CPU user time: 1.17 seconds. CPU system time: 0.01 seconds. Elapsed time: 1.18 seconds; current allocated memory: 463.949 MB.
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [HLS 200-111] Finished Checking Synthesizability: CPU user time: 0.74 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.75 seconds; current allocated memory: 489.656 MB.
# INFO: [XFORM 203-712] Applying dataflow to function 'myproject' (firmware/myproject.cpp:8), detected/extracted 6 process function(s):
# ...
# |19    |    U_myproject_fifo_w32_d360_A_ram                                                      |myproject_fifo_w32_d360_A_ram                                                              |     2|
# |20    |  layer7_out_U                                                                           |myproject_fifo_w18_d1_S                                                                    |    21|
# |21    |    U_myproject_fifo_w18_d1_S_ShiftReg                                                   |myproject_fifo_w18_d1_S_ShiftReg                                                           |    12|
# |22    |  pooling1d_cl_array_array_ap_ufixed_2_0_4_0_0_16u_config5_U0                            |myproject_pooling1d_cl_array_array_ap_ufixed_2_0_4_0_0_16u_config5_s                       |   696|
# |23    |  relu_array_ap_fixed_16u_array_ap_ufixed_2_0_4_0_0_16u_relu_config4_U0                  |myproject_relu_array_ap_fixed_16u_array_ap_ufixed_2_0_4_0_0_16u_relu_config4_s             |    79|
# |24    |    flow_control_loop_pipe_U                                                             |myproject_flow_control_loop_pipe                                                           |    25|
# |25    |  start_for_conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_21_10_5_3_0_16u_config2bkb_U     |myproject_start_for_conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_21_10_5_3_0_16u_config2bkb |    12|
# |26    |  start_for_dense_array_ap_ufixed_16u_array_ap_fixed_18_15_5_3_0_1u_config7_U0_U         |myproject_start_for_dense_array_ap_ufixed_16u_array_ap_fixed_18_15_5_3_0_1u_config7_U0     |    11|
# |27    |  start_for_hard_sigmoid_array_array_ap_ufixed_2_0_4_0_0_1u_hard_sigmoid_configcud_U     |myproject_start_for_hard_sigmoid_array_array_ap_ufixed_2_0_4_0_0_1u_hard_sigmoid_configcud |    13|
# |28    |  start_for_pooling1d_cl_array_array_ap_ufixed_2_0_4_0_0_16u_config5_U0_U                |myproject_start_for_pooling1d_cl_array_array_ap_ufixed_2_0_4_0_0_16u_config5_U0            |    11|
# |29    |  start_for_relu_array_ap_fixed_16u_array_ap_ufixed_2_0_4_0_0_16u_relu_config4_U0_U      |myproject_start_for_relu_array_ap_fixed_16u_array_ap_ufixed_2_0_4_0_0_16u_relu_config4_U0  |     8|
# |30    |  zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config10_U0                |myproject_zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config10_s           |   160|
# |31    |    grp_zeropad1d_cl_array_array_ap_fixed_16_6_5_3_0_1u_config10_Pipeline_CopyMain_fu_38 |myproject_zeropad1d_cl_array_array_ap_fixed_16_6_5_3_0_1u_config10_Pipeline_CopyMain       |    75|
# |32    |      flow_control_loop_pipe_sequential_init_U                                           |myproject_flow_control_loop_pipe_sequential_init_0                                         |    31|
# |33    |    grp_zeropad1d_cl_array_array_ap_fixed_16_6_5_3_0_1u_config10_Pipeline_PadRight_fu_46 |myproject_zeropad1d_cl_array_array_ap_fixed_16_6_5_3_0_1u_config10_Pipeline_PadRight       |    18|
# |34    |      flow_control_loop_pipe_sequential_init_U                                           |myproject_flow_control_loop_pipe_sequential_init                                           |    14|
# |35    |    regslice_both_input_1_U                                                              |myproject_regslice_both                                                                    |    57|
# +------+-----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------+------+
# ---------------------------------------------------------------------------------
# Finished Writing Synthesis Report : Time (s): cpu = 00:00:40 ; elapsed = 00:00:39 . Memory (MB): peak = 3123.145 ; gain = 1775.746 ; free physical = 14470 ; free virtual = 23362
# ---------------------------------------------------------------------------------
# Synthesis finished with 0 errors, 0 critical warnings and 497 warnings.
# Synthesis Optimization Runtime : Time (s): cpu = 00:00:40 ; elapsed = 00:00:39 . Memory (MB): peak = 3123.145 ; gain = 1775.746 ; free physical = 14469 ; free virtual = 23362
# Synthesis Optimization Complete : Time (s): cpu = 00:00:40 ; elapsed = 00:00:39 . Memory (MB): peak = 3123.152 ; gain = 1775.746 ; free physical = 14469 ; free virtual = 23362
# INFO: [Project 1-571] Translating synthesized netlist
# Netlist sorting complete. Time (s): cpu = 00:00:00.04 ; elapsed = 00:00:00.05 . Memory (MB): peak = 3123.152 ; gain = 0.000 ; free physical = 14755 ; free virtual = 23648
# INFO: [Netlist 29-17] Analyzing 263 Unisim elements for replacement
# INFO: [Netlist 29-28] Unisim Transformation completed in 0 CPU seconds
# INFO: [Project 1-570] Preparing netlist for logic optimization
# INFO: [Opt 31-138] Pushed 0 inverter(s) to 0 load pin(s).
# Netlist sorting complete. Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3179.172 ; gain = 0.000 ; free physical = 14753 ; free virtual = 23645
# INFO: [Project 1-111] Unisim Transformation Summary:
#   A total of 22 instances were transformed.
#   BUFG => BUFGCE: 1 instance
#   IBUF => IBUF (IBUFCTRL, INBUF): 21 instances
#
# Synth Design complete | Checksum: a5fce13
# INFO: [Common 17-83] Releasing license: Synthesis
# 118 Infos, 115 Warnings, 0 Critical Warnings and 0 Errors encountered.
# synth_design completed successfully
# synth_design: Time (s): cpu = 00:00:44 ; elapsed = 00:00:41 . Memory (MB): peak = 3179.207 ; gain = 1840.742 ; free physical = 14753 ; free virtual = 23645
# INFO: [Common 17-2834] synth_design peak Physical Memory [PSS] (MB): overall = 2822.002; main = 2680.641; forked = 431.474
# INFO: [Common 17-2834] synth_design peak Virtual Memory [VSS] (MB): overall = 3981.715; main = 3179.176; forked = 993.613
# # opt_design -retarget -propconst -sweep -bram_power_opt -shift_register_opt
# Command: opt_design -retarget -propconst -sweep -bram_power_opt -shift_register_opt
# Attempting to get a license for feature 'Implementation' and/or device 'xcu250'
# INFO: [Common 17-349] Got license for feature 'Implementation' and/or device 'xcu250'
# Running DRC as a precondition to command opt_design
#
# Starting DRC Task
# INFO: [DRC 23-27] Running DRC with 8 threads
# INFO: [Project 1-461] DRC finished with 0 Errors
# INFO: [Project 1-462] Please refer to the DRC report (report_drc) for more information.
#
# Time (s): cpu = 00:00:01 ; elapsed = 00:00:00.77 . Memory (MB): peak = 3243.203 ; gain = 63.996 ; free physical = 14747 ; free virtual = 23640
#
# Starting Cache Timing Information Task
# INFO: [Timing 38-35] Done setting XDC timing constraints.
# Ending Cache Timing Information Task | Checksum: 8f76ee93
#
# Time (s): cpu = 00:00:00.82 ; elapsed = 00:00:00.62 . Memory (MB): peak = 3282.781 ; gain = 39.578 ; free physical = 14747 ; free virtual = 23639
#
# Starting Logic Optimization Task
#
# Phase 1 Initialization
#
# Phase 1.1 Core Generation And Design Setup
# Phase 1.1 Core Generation And Design Setup | Checksum: 8f76ee93
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14587 ; free virtual = 23480
#
# Phase 1.2 Setup Constraints And Sort Netlist
# Phase 1.2 Setup Constraints And Sort Netlist | Checksum: 8f76ee93
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14587 ; free virtual = 23480
# Phase 1 Initialization | Checksum: 8f76ee93
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14587 ; free virtual = 23480
#
# Phase 2 Timer Update And Timing Data Collection
#
# Phase 2.1 Timer Update
# Phase 2.1 Timer Update | Checksum: 8f76ee93
#
# Time (s): cpu = 00:00:00.11 ; elapsed = 00:00:00.04 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14587 ; free virtual = 23479
#
# Phase 2.2 Timing Data Collection
# Phase 2.2 Timing Data Collection | Checksum: 8f76ee93
#
# Time (s): cpu = 00:00:00.12 ; elapsed = 00:00:00.05 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14587 ; free virtual = 23479
# Phase 2 Timer Update And Timing Data Collection | Checksum: 8f76ee93
#
# Time (s): cpu = 00:00:00.12 ; elapsed = 00:00:00.05 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14587 ; free virtual = 23479
#
# Phase 3 Retarget
# INFO: [Opt 31-1566] Pulled 4 inverters resulting in an inversion of 22 pins
# INFO: [Opt 31-138] Pushed 1 inverter(s) to 269 load pin(s).
# INFO: [Opt 31-49] Retargeted 0 cell(s).
# Phase 3 Retarget | Checksum: b78436c3
#
# Time (s): cpu = 00:00:00.26 ; elapsed = 00:00:00.14 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14587 ; free virtual = 23479
# Retarget | Checksum: b78436c3
# INFO: [Opt 31-389] Phase Retarget created 0 cells and removed 6 cells
#
# Phase 4 Constant propagation
# INFO: [Opt 31-138] Pushed 0 inverter(s) to 0 load pin(s).
# Phase 4 Constant propagation | Checksum: 0d8e3338
#
# Time (s): cpu = 00:00:00.3 ; elapsed = 00:00:00.17 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14587 ; free virtual = 23479
# Constant propagation | Checksum: 0d8e3338
# INFO: [Opt 31-389] Phase Constant propagation created 0 cells and removed 0 cells
#
# Phase 5 Sweep
# Phase 5 Sweep | Checksum: c000028d
#
# Time (s): cpu = 00:00:00.35 ; elapsed = 00:00:00.22 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14584 ; free virtual = 23477
# Sweep | Checksum: c000028d
# INFO: [Opt 31-389] Phase Sweep created 0 cells and removed 0 cells
#
# Phase 6 Shift Register Optimization
# INFO: [Opt 31-1064] SRL Remap converted 0 SRLs to 0 registers and converted 0 registers of register chains to 0 SRLs
# Phase 6 Shift Register Optimization | Checksum: c000028d
#
# Time (s): cpu = 00:00:00.36 ; elapsed = 00:00:00.23 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14584 ; free virtual = 23477
# Shift Register Optimization | Checksum: c000028d
# INFO: [Opt 31-389] Phase Shift Register Optimization created 0 cells and removed 0 cells
#
# Phase 7 Post Processing Netlist
# Phase 7 Post Processing Netlist | Checksum: c000028d
#
# Time (s): cpu = 00:00:00.37 ; elapsed = 00:00:00.24 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14584 ; free virtual = 23477
# Post Processing Netlist | Checksum: c000028d
# INFO: [Opt 31-389] Phase Post Processing Netlist created 0 cells and removed 0 cells
#
# Phase 8 Finalization
#
# Phase 8.1 Finalizing Design Cores and Updating Shapes
# Phase 8.1 Finalizing Design Cores and Updating Shapes | Checksum: 45f36e78
#
# Time (s): cpu = 00:00:00.52 ; elapsed = 00:00:00.33 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14585 ; free virtual = 23477
#
# Phase 8.2 Verifying Netlist Connectivity
# Phase 8.2 Verifying Netlist Connectivity | Checksum: 45f36e78
#
# Time (s): cpu = 00:00:00.52 ; elapsed = 00:00:00.33 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14585 ; free virtual = 23477
# Phase 8 Finalization | Checksum: 45f36e78
#
# Time (s): cpu = 00:00:00.52 ; elapsed = 00:00:00.33 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14585 ; free virtual = 23477
# Opt_design Change Summary
# =========================
#
#
# -------------------------------------------------------------------------------------------------------------------------
# |  Phase                        |  #Cells created  |  #Cells Removed  |  #Constrained objects preventing optimizations  |
# -------------------------------------------------------------------------------------------------------------------------
# |  Retarget                     |               0  |               6  |                                              0  |
# |  Constant propagation         |               0  |               0  |                                              0  |
# |  Sweep                        |               0  |               0  |                                              0  |
# |  Shift Register Optimization  |               0  |               0  |                                              0  |
# |  Post Processing Netlist      |               0  |               0  |                                              0  |
# -------------------------------------------------------------------------------------------------------------------------
#
#
# Ending Logic Optimization Task | Checksum: 45f36e78
#
# Time (s): cpu = 00:00:00.52 ; elapsed = 00:00:00.33 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14585 ; free virtual = 23477
# INFO: [Constraints 18-11670] Building netlist checker database with flags, 0x8
# Done building netlist checker database: Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3452.766 ; gain = 0.000 ; free physical = 14585 ; free virtual = 23477
#
# Starting Power Optimization Task
# INFO: [Pwropt 34-132] Skipping clock gating for clocks with a period < 2.00 ns.
# INFO: [Pwropt 34-9] Applying IDT optimizations ...
# INFO: [Pwropt 34-10] Applying ODC optimizations ...
# INFO: [Timing 38-35] Done setting XDC timing constraints.
# WARNING: [Power 33-232] No user defined clocks were found in the design! Power estimation will be inaccurate until this is corrected.
# Resolution: Please specify clocks using create_clock/create_generated_clock for sequential elements. For pure combinatorial circuits, please specify a virtual clock, otherwise the vectorless estimation might be inaccurate
# Running Vector-less Activity Propagation...
#
# Finished Running Vector-less Activity Propagation
#
#
# Starting PowerOpt Patch Enables Task
# INFO: [Pwropt 34-162] WRITE_MODE attribute of 0 BRAM(s) out of a total of 4 has been updated to save power. Run report_power_opt to get a complete listing of the BRAMs updated.
# INFO: [Pwropt 34-201] Structural ODC has moved 3 WE to EN ports
# Number of BRAM Ports augmented: 0 newly gated: 4 Total Ports: 8
# Ending PowerOpt Patch Enables Task | Checksum: 18fc40cb8
#
# Time (s): cpu = 00:00:00.04 ; elapsed = 00:00:00.02 . Memory (MB): peak = 3714.406 ; gain = 0.000 ; free physical = 14469 ; free virtual = 23362
# Ending Power Optimization Task | Checksum: 18fc40cb8
#
# Time (s): cpu = 00:00:08 ; elapsed = 00:00:06 . Memory (MB): peak = 3714.406 ; gain = 261.641 ; free physical = 14469 ; free virtual = 23362
#
# Starting Final Cleanup Task
# Ending Final Cleanup Task | Checksum: 18fc40cb8
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3714.406 ; gain = 0.000 ; free physical = 14469 ; free virtual = 23362
#
# Starting Netlist Obfuscation Task
# Netlist sorting complete. Time (s): cpu = 00:00:00 ; elapsed = 00:00:00.01 . Memory (MB): peak = 3714.406 ; gain = 0.000 ; free physical = 14469 ; free virtual = 23362
# Ending Netlist Obfuscation Task | Checksum: eff640d3
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00.01 . Memory (MB): peak = 3714.406 ; gain = 0.000 ; free physical = 14469 ; free virtual = 23362
# INFO: [Common 17-83] Releasing license: Implementation
# 23 Infos, 1 Warnings, 0 Critical Warnings and 0 Errors encountered.
# opt_design completed successfully
# opt_design: Time (s): cpu = 00:00:11 ; elapsed = 00:00:08 . Memory (MB): peak = 3714.406 ; gain = 535.199 ; free physical = 14469 ; free virtual = 23362
# # report_utilization -file vivado_synth.rpt
# INFO: [Common 17-206] Exiting Vivado at Mon Jul 21 15:35:33 2025...
# ***** VIVADO SYNTHESIS COMPLETED IN 0h1m5s *****
# INFO: [HLS 200-112] Total CPU user time: 266.71 seconds. Total CPU system time: 4.24 seconds. Total elapsed time: 284.34 seconds; peak allocated memory: 1.085 GB.
# INFO: [Common 17-206] Exiting vitis_hls at Mon Jul 21 15:35:44 2025...
# Cosim report not found.
# Timing report not found.
# {'CSynthesisReport': {'TargetClockPeriod': '5.00',
#   'EstimatedClockPeriod': '3.491',
#   'BestLatency': '2898',
#   'WorstLatency': '2898',
#   'IntervalMin': '2890',
#   'IntervalMax': '2890',
#   'BRAM_18K': '18',
#   'FF': '8097',
#   'LUT': '22668',
#   'DSP': '0',
#   'URAM': '0',
#   'AvailableBRAM_18K': '5376',
#   'AvailableDSP': '12288',
#   'AvailableFF': '3456000',
#   'AvailableLUT': '1728000',
#   'AvailableURAM': '1280'},
#  'VivadoSynthReport': {'LUT': '4796',
#   'FF': '5567',
#   'BRAM_18K': '3.5',
#   'URAM': '5',
#   'DSP48E': '0'}}

# %% [markdown]
# ## Check the reports

# %%
hls4ml.report.read_vivado_report('hls4ml/QKeras_model_4_2bits/')
# Out:
# Found 1 solution(s) in hls4ml/QKeras_model_4_2bits//myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vitis HLS Report for 'myproject'
# ================================================================
# * Date:           Mon Jul 21 15:34:21 2025
#
# * Version:        2023.2 (Build 4023990 on Oct 11 2023)
# * Project:        myproject_prj
# * Solution:       solution1 (Vivado IP Flow Target)
# * Product family: virtexuplus
# * Target device:  xcu250-figd2104-2L-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  |  5.00 ns|  3.491 ns|     1.35 ns|
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+------+------+----------+
#     |  Latency (cycles) |   Latency (absolute)  |   Interval  | Pipeline |
#     |   min   |   max   |    min    |    max    |  min |  max |   Type   |
#     +---------+---------+-----------+-----------+------+------+----------+
#     |     2898|     2898|  14.490 us|  14.490 us|  2890|  2890|  dataflow|
#     +---------+---------+-----------+-----------+------+------+----------+
#
#     + Detail:
#         * Instance:
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+---------+
#         |                                                                         |                                                                        |  Latency (cycles) |   Latency (absolute)  |   Interval  | Pipeline|
#         |                                 Instance                                |                                 Module                                 |   min   |   max   |    min    |    max    |  min |  max |   Type  |
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+---------+
#         |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config10_U0  |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config10_s  |     1451|     1451|   7.255 us|   7.255 us|  1451|  1451|       no|
#         |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_21_10_5_3_0_16u_config2_U0   |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_21_10_5_3_0_16u_config2_s   |     2889|     2889|  14.445 us|  14.445 us|  2889|  2889|       no|
#         |relu_array_ap_fixed_16u_array_ap_ufixed_2_0_4_0_0_16u_relu_config4_U0    |relu_array_ap_fixed_16u_array_ap_ufixed_2_0_4_0_0_16u_relu_config4_s    |     1443|     1443|   7.215 us|   7.215 us|  1443|  1443|       no|
#         |pooling1d_cl_array_array_ap_ufixed_2_0_4_0_0_16u_config5_U0              |pooling1d_cl_array_array_ap_ufixed_2_0_4_0_0_16u_config5_s              |     1443|     1443|   7.215 us|   7.215 us|  1443|  1443|       no|
#         |dense_array_ap_ufixed_16u_array_ap_fixed_18_15_5_3_0_1u_config7_U0       |dense_array_ap_ufixed_16u_array_ap_fixed_18_15_5_3_0_1u_config7_s       |      371|      371|   1.855 us|   1.855 us|   371|   371|       no|
#         |hard_sigmoid_array_array_ap_ufixed_2_0_4_0_0_1u_hard_sigmoid_config9_U0  |hard_sigmoid_array_array_ap_ufixed_2_0_4_0_0_1u_hard_sigmoid_config9_s  |        3|        3|  15.000 ns|  15.000 ns|     3|     3|       no|
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+---------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +---------------------+---------+-------+---------+---------+------+
# |         Name        | BRAM_18K|  DSP  |    FF   |   LUT   | URAM |
# +---------------------+---------+-------+---------+---------+------+
# |DSP                  |        -|      -|        -|        -|     -|
# |Expression           |        -|      -|        0|        2|     -|
# |FIFO                 |       18|      -|     1377|      811|     -|
# |Instance             |        -|      -|     6720|    21855|     -|
# |Memory               |        -|      -|        -|        -|     -|
# |Multiplexer          |        -|      -|        -|        -|     -|
# |Register             |        -|      -|        -|        -|     -|
# +---------------------+---------+-------+---------+---------+------+
# |Total                |       18|      0|     8097|    22668|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available SLR        |     1344|   3072|   864000|   432000|   320|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization SLR (%)  |        1|      0|       ~0|        5|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available            |     5376|  12288|  3456000|  1728000|  1280|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization (%)      |       ~0|      0|       ~0|        1|     0|
# +---------------------+---------+-------+---------+---------+------+
#
# + Detail:
#     * Instance:
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+----+------+-------+-----+
#     |                                 Instance                                |                                 Module                                 | BRAM_18K| DSP|  FF  |  LUT  | URAM|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+----+------+-------+-----+
#     |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_21_10_5_3_0_16u_config2_U0   |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_21_10_5_3_0_16u_config2_s   |        0|   0|   520|   1311|    0|
#     |dense_array_ap_ufixed_16u_array_ap_fixed_18_15_5_3_0_1u_config7_U0       |dense_array_ap_ufixed_16u_array_ap_fixed_18_15_5_3_0_1u_config7_s       |        0|   0|  5674|  16669|    0|
#     |hard_sigmoid_array_array_ap_ufixed_2_0_4_0_0_1u_hard_sigmoid_config9_U0  |hard_sigmoid_array_array_ap_ufixed_2_0_4_0_0_1u_hard_sigmoid_config9_s  |        0|   0|    25|    156|    0|
#     |pooling1d_cl_array_array_ap_ufixed_2_0_4_0_0_16u_config5_U0              |pooling1d_cl_array_array_ap_ufixed_2_0_4_0_0_16u_config5_s              |        0|   0|   407|   1421|    0|
#     |relu_array_ap_fixed_16u_array_ap_ufixed_2_0_4_0_0_16u_relu_config4_U0    |relu_array_ap_fixed_16u_array_ap_ufixed_2_0_4_0_0_16u_relu_config4_s    |        0|   0|    49|   2025|    0|
#     |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config10_U0  |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config10_s  |        0|   0|    45|    273|    0|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+----+------+-------+-----+
#     |Total                                                                    |                                                                        |        0|   0|  6720|  21855|    0|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+----+------+-------+-----+
#
#     * DSP:
#     N/A
#
#     * Memory:
#     N/A
#
#     * FIFO:
#     +---------------+---------+------+----+-----+------+-----+---------+
#     |      Name     | BRAM_18K|  FF  | LUT| URAM| Depth| Bits| Size:D*B|
#     +---------------+---------+------+----+-----+------+-----+---------+
#     |layer10_out_U  |        1|    63|   0|    -|  1443|   16|    23088|
#     |layer2_out_U   |       15|  1056|   0|    -|  1440|  336|   483840|
#     |layer4_out_U   |        1|    95|   0|    -|  1440|   32|    46080|
#     |layer5_out_U   |        1|    95|   0|    -|   360|   32|    11520|
#     |layer7_out_U   |        0|    68|   0|    -|     1|   18|       18|
#     +---------------+---------+------+----+-----+------+-----+---------+
#     |Total          |       18|  1377|   0|    0|  4684|  434|   564546|
#     +---------------+---------+------+----+-----+------+-----+---------+
#
#     * Expression:
#     +--------------+----------+----+---+----+------------+------------+
#     | Variable Name| Operation| DSP| FF| LUT| Bitwidth P0| Bitwidth P1|
#     +--------------+----------+----+---+----+------------+------------+
#     |ap_idle       |       and|   0|  0|   2|           1|           1|
#     +--------------+----------+----+---+----+------------+------------+
#     |Total         |          |   0|  0|   2|           1|           1|
#     +--------------+----------+----+---+----+------------+------------+
#
#     * Multiplexer:
#     N/A
#
#     * Register:
#     N/A
#
#
#
# ================================================================
# == Interface
# ================================================================
# * Summary:
# +-------------------+-----+-----+------------+--------------+--------------+
# |     RTL Ports     | Dir | Bits|  Protocol  | Source Object|    C Type    |
# +-------------------+-----+-----+------------+--------------+--------------+
# |input_1_TDATA      |   in|   16|        axis|       input_1|       pointer|
# |input_1_TVALID     |   in|    1|        axis|       input_1|       pointer|
# |input_1_TREADY     |  out|    1|        axis|       input_1|       pointer|
# |layer9_out_TDATA   |  out|    8|        axis|    layer9_out|       pointer|
# |layer9_out_TVALID  |  out|    1|        axis|    layer9_out|       pointer|
# |layer9_out_TREADY  |   in|    1|        axis|    layer9_out|       pointer|
# |ap_clk             |   in|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_rst_n           |   in|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_start           |   in|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_done            |  out|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_ready           |  out|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_idle            |  out|    1|  ap_ctrl_hs|     myproject|  return value|
# +-------------------+-----+-----+------------+--------------+--------------+
#
# Co-simulation report not found.
