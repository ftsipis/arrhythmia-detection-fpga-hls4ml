# %% [markdown]
# # Detecting arrythmia using Deep Leaning

# %% [markdown]
# ## Loading modules

# %%
import pandas as pd
import numpy as np
import wfdb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, TimeDistributed
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Download Dataset

# %%
from pathlib import Path
import zipfile

database_filename = "mit-bih-arrhythmia-database-1.0.0.zip"
expected_file = Path("mit-bih-arrhythmia-database-1.0.0")

if not expected_file.exists():
    with zipfile.ZipFile(database_filename, 'r') as zip_ref:
        zip_ref.extractall(".")
    print("Extraction complete.")
else:
    print("Files already extracted.")
# Out:
# Files already extracted.

# %% [markdown]
# ## Loading data

# %% [markdown]
# Loading list of records available, from dataset available [here](https://physionet.org/content/mitdb/1.0.0/)

# %%
records = np.loadtxt("mit-bih-arrhythmia-database-1.0.0/RECORDS", dtype=int)

# %% [markdown]
# Defining invalid beats as well as abnormal beats, according to [Physiobank](https://archive.physionet.org/physiobank/annotations.shtml)

# %%
invalid_beat = [
    "[", "!", "]", "x", "(", ")", "p", "t", 
    "u", "`", "'", "^", "|", "~", "+", "s", 
    "T", "*", "D", "=", '"', "@"
]

abnormal_beats = [
    "L", "R", "B", "A", "a", "J", "S", "V", 
    "r", "F", "e", "j", "n", "E", "/", "f", "Q", "?"
]

# %% [markdown]
# ## Processing dataset

# %% [markdown]
# This function classify a beat according to its symbol and the list provided above.

# %%
def classify_beat(symbol):
    if symbol in abnormal_beats:
        return 1
    elif symbol == "N" or symbol == ".":
        return 0

# %% [markdown]
# Given a signal, the beat location, and the window to be used as a sequence, this function gets the sequence. It will return an empty array in case of an invalid beat or empty sequence.

# %%
def get_sequence(signal, beat_loc, window_sec, fs):
    window_one_side = window_sec * fs
    beat_start = beat_loc - window_one_side
    beat_end = beat_loc + window_one_side
    if beat_end < signal.shape[0]:
        sequence = signal[beat_start:beat_end, 0]
        return sequence.reshape(1, -1, 1)
    else:
        return np.array([])

# %% [markdown]
# The code below will build a list of labels and sequences as well as map the sequences for each patient. The percentage calculated represents the ratio of abnormal beats in each patient data.

# %%
all_sequences = []
all_labels = []
window_sec = 3
subject_map = []
for subject in records:
    record = wfdb.rdrecord(f'mit-bih-arrhythmia-database-1.0.0/{subject}')
    annotation = wfdb.rdann(f'mit-bih-arrhythmia-database-1.0.0/{subject}', 'atr')
    atr_symbol = annotation.symbol
    atr_sample = annotation.sample
    fs = record.fs
    scaler = StandardScaler()
    signal = scaler.fit_transform(record.p_signal)
    subject_labels = []
    for i, i_sample in enumerate(atr_sample):
        label = classify_beat(atr_symbol[i])
        sequence = get_sequence(signal, i_sample, window_sec, fs)
        if label is not None and sequence.size > 0:
            all_sequences.append(sequence)
            subject_labels.append(label)

    normal_percentage = sum(subject_labels) / len(subject_labels)
    subject_map.append({
        "subject": subject,
        "percentage": normal_percentage,
        "num_seq": len(subject_labels),
        "start": len(all_labels),
        "end": len(all_labels)+len(subject_labels)
    })
    all_labels.extend(subject_labels)

# %%
print(subject_map[:5])
# Out:
# [{'subject': 100, 'percentage': 0.014977973568281937, 'num_seq': 2270, 'start': 0, 'end': 2270}, {'subject': 101, 'percentage': 0.0026838432635534087, 'num_seq': 1863, 'start': 2270, 'end': 4133}, {'subject': 102, 'percentage': 0.9546910755148741, 'num_seq': 2185, 'start': 4133, 'end': 6318}, {'subject': 103, 'percentage': 0.0009606147934678194, 'num_seq': 2082, 'start': 6318, 'end': 8400}, {'subject': 104, 'percentage': 0.926774483378257, 'num_seq': 2226, 'start': 8400, 'end': 10626}]

# %% [markdown]
# Creating bins to be used to stratify the train and validation split.

# %%
subject_map = pd.DataFrame(subject_map)

# %%
print(subject_map[:5])
# Out:
#    subject  percentage  num_seq  start    end
# 0      100    0.014978     2270      0   2270
# 1      101    0.002684     1863   2270   4133
# 2      102    0.954691     2185   4133   6318
# 3      103    0.000961     2082   6318   8400
# 4      104    0.926774     2226   8400  10626

# %% [markdown]
# The code presented will create class in each patient is segmented.

# %%
bins = [0, 0.2, 0.6, 1.0]
subject_map["bin"] = pd.cut(subject_map['percentage'], bins=bins, labels=False, include_lowest=True)

# %%
print(subject_map[:5])
# Out:
#    subject  percentage  num_seq  start    end  bin
# 0      100    0.014978     2270      0   2270    0
# 1      101    0.002684     1863   2270   4133    0
# 2      102    0.954691     2185   4133   6318    2
# 3      103    0.000961     2082   6318   8400    0
# 4      104    0.926774     2226   8400  10626    2

# %% [markdown]
# Now, the dataset is split into train and validation, stratifying by the bin defined above.

# %%
train, validation = train_test_split(subject_map, test_size=0.25, stratify=subject_map["bin"], random_state=42)

# %% [markdown]
# This function build a dataset based on the map for each split.

# %%
def build_dataset(df, all_sequences, all_labels):
    sequences = []
    labels = []
    for i, row in df.iterrows():
        start = int(row["start"])
        end = int(row["end"])
        sequences.extend(all_sequences[start:end])
        labels.extend(all_labels[start:end])
        
    return np.vstack(sequences), np.vstack(labels)

# %%
X_train, y_train = build_dataset(train, all_sequences, all_labels)
X_val, y_val = build_dataset(validation, all_sequences, all_labels)

# %%
X_train.shape, y_train.shape
# Out:
# ((83059, 720, 1), (83059, 1))

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### CNN model

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from keras.optimizers import Adam

sequence_size = X_train.shape[1]
n_features = 1

cnn_model = Sequential([
    Conv1D(
        filters=16,
        kernel_size=4,
        strides=1,
        input_shape=(sequence_size, n_features),
        padding="same",
        activation="relu"
    ),
    MaxPooling1D(pool_size=4),
    Flatten(),
    Dropout(0.5),
    Dense(1, activation="sigmoid", name="output")
])

cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 720, 16)           80
#
#  max_pooling1d (MaxPooling1  (None, 180, 16)           0
#  D)
#
#  flatten (Flatten)           (None, 2880)              0
#
#  dropout (Dropout)           (None, 2880)              0
#
#  output (Dense)              (None, 1)                 2881
#
# =================================================================
# Total params: 2961 (11.57 KB)
# Trainable params: 2961 (11.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.sparsity import keras as sparsity
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow_model_optimization.sparsity.keras import UpdatePruningStep
import json

# Define the pruning parameters
NSTEPS = int(X_train.shape[0]) // 128

pruning_params = {
    'pruning_schedule': sparsity.PolynomialDecay(
        initial_sparsity=0.0,
        final_sparsity=0.5,
        begin_step=NSTEPS * 2,
        end_step=NSTEPS * 15,
        frequency=NSTEPS
    )
}

# Function to apply pruning to the layers
def pruneFunction(layer):
    if isinstance(layer, tfmot.sparsity.keras.prune_wrapper.PruneLowMagnitude):  # skip already pruned
        return layer
    if isinstance(layer, tfmot.sparsity.keras.PrunableLayer):
        if isinstance(layer, Dense) and layer.name == 'output':
            return layer
        return tfmot.sparsity.keras.prune_low_magnitude(layer, **pruning_params)
    if isinstance(layer, Conv1D):
        return tfmot.sparsity.keras.prune_low_magnitude(layer, **pruning_params)
    return layer

# Apply pruning to the model
pruned_model = tfmot.sparsity.keras.prune_low_magnitude(
    cnn_model,
    **pruning_params
)

# Compile the pruned model
optimizer = Adam(learning_rate=0.001)
pruned_model.compile(
    optimizer=optimizer,
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

pruned_model.summary()

# Define the pruning callback
pruning_callbacks = [UpdatePruningStep()]

# Training process
train = False
if train:
    hist_cnn = pruned_model.fit(
        X_train, 
        y_train, 
        batch_size=128,
        epochs=15,
        validation_data=(X_val, y_val),
        callbacks=pruning_callbacks  # Add the pruning callback
    )
    pruned_model.save('Model4_prune/pruned_cnn_model.keras')

    # Save training history
    with open('Model4_prune/hist_cnn.json', 'w') as f:
        json.dump(hist_cnn.history, f)

    with open('Model4_prune/hist_cnn.json', 'r') as f:
        hist_cnn = json.load(f)
else:

    from qkeras.utils import _add_supported_quantized_objects
    from tensorflow_model_optimization.python.core.sparsity.keras import pruning_wrapper

    co = {}
    _add_supported_quantized_objects(co)
    co['PruneLowMagnitude'] = pruning_wrapper.PruneLowMagnitude
    
    # Load pre-trained pruned model and history
    pruned_model = load_model('Model4_prune/pruned_cnn_model.keras', custom_objects=co)
    
    with open('Model4_prune/hist_cnn.json', 'r') as f:
        hist_cnn = json.load(f)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prune_low_magnitude_conv1d  (None, 720, 16)           146
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_max_po  (None, 180, 16)           1
#  oling1d (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_flatte  (None, 2880)              1
#  n (PruneLowMagnitude)
#
#  prune_low_magnitude_dropou  (None, 2880)              1
#  t (PruneLowMagnitude)
#
#  prune_low_magnitude_output  (None, 1)                 5763
#   (PruneLowMagnitude)
#
# =================================================================
# Total params: 5912 (23.11 KB)
# Trainable params: 2961 (11.57 KB)
# Non-trainable params: 2951 (11.55 KB)
# _________________________________________________________________

# %%
pruned_model.evaluate(X_val, y_val)
# Out:
# 823/823 [==============================] - 1s 529us/step - loss: 0.5771 - accuracy: 0.8233
# [0.5770698189735413, 0.8233327269554138]

# %%
# summarize history for accuracy
plt.plot(hist_cnn['accuracy'])
plt.plot(hist_cnn['val_accuracy'])
plt.title('CNN model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist_cnn['loss'])
plt.plot(hist_cnn['val_loss'])
plt.title('CNN model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Make an hls4ml config & model

# %%
from tensorflow_model_optimization.sparsity.keras import strip_pruning
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_wrapper

from qkeras.utils import _add_supported_quantized_objects

co = {}
_add_supported_quantized_objects(co)
co['PruneLowMagnitude'] = pruning_wrapper.PruneLowMagnitude

model = tf.keras.models.load_model('Model4_prune/pruned_cnn_model.keras', custom_objects=co)
model = strip_pruning(model)

# %%
import hls4ml
import plotting 

os.environ['PATH'] = os.environ['XILINX_VITIS'] + '/bin:' + os.environ['PATH']
config = hls4ml.utils.config_from_keras_model(model, granularity='name', backend='Vitis')
config['Model']['Precision'] = 'ap_fixed<16,6>'
print("-----------------------------------")
print("Configuration")
plotting.print_dict(config)
print("-----------------------------------")

config['LayerName']['conv1d']['Precision']['weight'] = 'ap_fixed<8,4>'
config['LayerName']['conv1d']['Precision']['bias'] = 'ap_fixed<8,4>'

config['LayerName']['output']['Precision']['weight'] = 'ap_fixed<8,4>'
config['LayerName']['output']['Precision']['bias'] = 'ap_fixed<8,4>'

hls_model = hls4ml.converters.convert_from_keras_model(model, hls_config=config, backend='Vitis', output_dir='hls4ml/Model4_prune_8b', part='xcu250-figd2104-2L-e', io_type='io_stream')
# Out:
# Interpreting Sequential
# Topology:
# Layer name: conv1d_input, layer type: InputLayer, input shapes: [[None, 720, 1]], output shape: [None, 720, 1]
# Layer name: conv1d, layer type: Conv1D, input shapes: [[None, 720, 1]], output shape: [None, 720, 16]
# Layer name: max_pooling1d, layer type: MaxPooling1D, input shapes: [[None, 720, 16]], output shape: [None, 180, 16]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 180, 16]], output shape: [None, 2880]
# Layer name: output, layer type: Dense, input shapes: [[None, 2880]], output shape: [None, 1]
# -----------------------------------
# Configuration
# Model
#   Precision:         ap_fixed<16,6>
#   ReuseFactor:       1
#   Strategy:          Latency
#   BramFactor:        1000000000
#   TraceOutput:       False
# LayerName
#   conv1d_input
#     Trace:           False
#     Precision
#       result:        auto
#   conv1d
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#     ParallelizationFactor:1
#     ConvImplementation:LineBuffer
#   conv1d_relu
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   max_pooling1d
#     Trace:           False
#     Precision
#       result:        auto
#       accum:         auto
#     ReuseFactor:     1
#     ConvImplementation:LineBuffer
#   flatten
#     Trace:           False
#     Precision
#       result:        auto
#   output
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#   output_sigmoid
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
# -----------------------------------
# Interpreting Sequential
# Topology:
# Layer name: conv1d_input, layer type: InputLayer, input shapes: [[None, 720, 1]], output shape: [None, 720, 1]
# Layer name: conv1d, layer type: Conv1D, input shapes: [[None, 720, 1]], output shape: [None, 720, 16]
# Layer name: max_pooling1d, layer type: MaxPooling1D, input shapes: [[None, 720, 16]], output shape: [None, 180, 16]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 180, 16]], output shape: [None, 2880]
# Layer name: output, layer type: Dense, input shapes: [[None, 2880]], output shape: [None, 1]
# Creating HLS model

# %% [markdown]
# ## Visualise the model architecture

# %%
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=None)

# %% [markdown]
# ## Compile, predict

# %%
hls_model.compile()
X_val = np.ascontiguousarray(X_val)
y_hls = hls_model.predict(X_val)
# Out:
# Writing HLS project
# Done

# %% [markdown]
# ## HLS4ML Model Accuracy

# %%
from sklearn.metrics import accuracy_score

# Convert predictions to binary labels using a threshold of 0.5
y_hls_pred   = (y_hls > 0.5).astype(int)

# Calculate accuracy using ground truth y_val
acc_hls   = accuracy_score(y_val, y_hls_pred)

print("HLS4ML Model Accuracy: {:.2f}%".format(acc_hls * 100))
# Out:
# HLS4ML Model Accuracy: 78.90%

# %% [markdown]
# ## Synthesize

# %%
hls_model.build(csim=False, synth=True, vsynth=True, export=True)
# Out:
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2023.2 (64-bit)
#   **** SW Build 4023990 on Oct 11 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis_HLS/2023.2/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vitis_HLS/2023.2/bin/unwrapped/lnx64.o/vitis_hls'
# INFO: [HLS 200-10] For user 'fotis' on host 'fotis-Z390-UD' (Linux_x86_64 version 6.8.0-64-generic) on Sat Jul 19 13:46:55 EEST 2025
# INFO: [HLS 200-10] On os Ubuntu 24.04.2 LTS
# INFO: [HLS 200-10] In directory '/home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b'
# INFO: [HLS 200-2053] The vitis_hls executable is being deprecated. Consider using vitis-run --mode hls --tcl
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-1510] Running: open_project myproject_prj
# INFO: [HLS 200-10] Creating and opening project '/home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj'.
# INFO: [HLS 200-1510] Running: set_top myproject
# INFO: [HLS 200-1510] Running: add_files firmware/myproject.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb myproject_test.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb firmware/weights
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-1510] Running: add_files -tb tb_data
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-1510] Running: open_solution solution1
# INFO: [HLS 200-10] Creating and opening solution '/home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1510] Running: config_array_partition -maximum_size 4096
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# ERROR: [HLS 200-642] The 'config_array_partition -maximum_size' command is not supported.
# INFO: [HLS 200-1510] Running: config_compile -name_max_length 80
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: set_part xcu250-figd2104-2L-e
# INFO: [HLS 200-1611] Setting target device to 'xcu250-figd2104-2L-e'
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: config_schedule -enable_dsp_full_reg=false
# INFO: [HLS 200-1510] Running: create_clock -period 5 -name default
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [HLS 200-1510] Running: set_clock_uncertainty 27% default
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 1.35ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [HLS 200-1510] Running: csynth_design
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 0.03 seconds. CPU system time: 0 seconds. Elapsed time: 0.03 seconds; current allocated memory: 282.168 MB.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:33:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:107:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:189:9)
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:38:79)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:38:83)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:51:74)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:51:78)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 200-471] Dataflow form checks found 4 issue(s) in file firmware/myproject.cpp
# Resolution: For help on HLS 200-471 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-471.html
# WARNING: [HLS 207-5292] unused parameter 'keep' (firmware/nnet_utils/nnet_helpers.h:285:99)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:14:36)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:15:36)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:16:44)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:24:24)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:25:24)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:26:32)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:33:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:33:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:34:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:35:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:42:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:42:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:43:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:44:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:51:29)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:51:80)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:52:50)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:53:48)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:16:39)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_code_gen.h:17:38)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_code_gen.h:18:60)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_code_gen.h:19:58)
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 4.29 seconds. CPU system time: 0.37 seconds. Elapsed time: 4.68 seconds; current allocated memory: 290.434 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# INFO: [HLS 200-1995] There were 4,019 instructions in the design after the 'Compile/Link' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# WARNING: [HLS 200-1995] There were 181,542 instructions in the design after the 'Unroll/Inline (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 41,817 instructions in the design after the 'Unroll/Inline (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 30,201 instructions in the design after the 'Unroll/Inline (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 29,811 instructions in the design after the 'Unroll/Inline (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 36,233 instructions in the design after the 'Array/Struct (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 17,930 instructions in the design after the 'Array/Struct (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 17,942 instructions in the design after the 'Array/Struct (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 18,588 instructions in the design after the 'Array/Struct (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 19,858 instructions in the design after the 'Array/Struct (step 5)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 13,988 instructions in the design after the 'Performance (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 13,976 instructions in the design after the 'Performance (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 13,974 instructions in the design after the 'Performance (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 13,974 instructions in the design after the 'Performance (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 13,831 instructions in the design after the 'HW Transforms (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 13,934 instructions in the design after the 'HW Transforms (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/Model4_prune_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>' (firmware/nnet_utils/nnet_pooling_stream.h:182:9)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config6>' (firmware/nnet_utils/nnet_dense_stream.h:85:9)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>*, config6::weight_t*, config6::bias_t*)', Pragma conflict happens on 'INLINE' and 'PIPELINE' pragmas: same function (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config8>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config8>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:33:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_data<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config8>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config8>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:38:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config8>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config8>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:43:9)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2_mult::weight_t*, config2_mult::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:347:5)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseLatency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>::dense(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:354:9)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long) const (.16)' into 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.15)' (firmware/nnet_utils/nnet_conv_stream.h:176:37)
# INFO: [HLS 214-131] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.12)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.14)' (firmware/nnet_utils/nnet_common.h:44:16)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.14)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.11)' (firmware/nnet_utils/nnet_common.h:46:15)
# INFO: [HLS 214-131] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.12)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.11)' (firmware/nnet_utils/nnet_common.h:46:12)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.14)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.11)' (firmware/nnet_utils/nnet_common.h:46:44)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.11)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_pool<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*) (.10)' (firmware/nnet_utils/nnet_pooling_stream.h:21:16)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.15)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.8)' (firmware/nnet_utils/nnet_pooling_stream.h:142:5)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long) (.5)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.8)' (firmware/nnet_utils/nnet_pooling_stream.h:157:13)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_pool<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, config4>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*) (.10)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.8)' (firmware/nnet_utils/nnet_pooling_stream.h:157:30)
# INFO: [HLS 214-131] Inlining function 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.8)' into 'void nnet::pooling1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_pooling_stream.h:187:2)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long) (.5)' into 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.4)' (firmware/nnet_utils/nnet_dense_stream.h:39:39)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>*, config6::weight_t*, config6::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long) (.3)' into 'void nnet::res_write<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config6>(nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*, hls::stream<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&) (.1)' (firmware/nnet_utils/nnet_dense_stream.h:75:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::data_prepare<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.4)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config6>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, config6::weight_t*, config6::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:93:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::res_write<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config6>(nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*, hls::stream<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&) (.1)' into 'void nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config6>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, config6::weight_t*, config6::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:100:5)
# INFO: [HLS 214-291] Loop 'SigmoidPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:88:9)
# INFO: [HLS 214-291] Loop 'DataPackPipeline' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_stream.h:37:13)
# INFO: [HLS 214-291] Loop 'Result' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:64:5)
# INFO: [HLS 214-291] Loop 'Accum1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:54:5)
# INFO: [HLS 214-291] Loop 'Accum2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:56:9)
# INFO: [HLS 214-291] Loop 'ResetAccum' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:48:5)
# INFO: [HLS 214-291] Loop 'Product1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:37:5)
# INFO: [HLS 214-291] Loop 'Product2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:40:9)
# INFO: [HLS 214-291] Loop 'KernelShiftWidth' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:161:5)
# INFO: [HLS 214-291] Loop 'KernelShiftChannel' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:164:9)
# INFO: [HLS 214-291] Loop 'KernelPushChannel' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:174:5)
# INFO: [HLS 214-291] Loop 'FiltLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_pooling_stream.h:147:9)
# INFO: [HLS 214-291] Loop 'PoolLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_pooling_stream.h:152:13)
# INFO: [HLS 214-291] Loop 'ReLUPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:49:9)
# INFO: [HLS 214-291] Loop 'CastLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:359:9)
# INFO: [HLS 214-186] Unrolling loop 'SigmoidPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:88:9) in function 'nnet::sigmoid<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, sigmoid_config7>' completely with a factor of 1 (firmware/nnet_utils/nnet_activation_stream.h:65:0)
# INFO: [HLS 214-186] Unrolling loop 'ResPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:73:9) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config6>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'DataPackPipeline' (firmware/nnet_utils/nnet_dense_stream.h:37:13) in function 'nnet::dense<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config6>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' completely with a factor of 2880 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' completely with a factor of 2880 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>' completely with a factor of 3 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# WARNING: [HLS 214-189] Pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>' has been removed because the loop is unrolled completely (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:164:9) in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>' completely with a factor of 16 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelPushChannel' (firmware/nnet_utils/nnet_conv_stream.h:174:5) in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>' completely with a factor of 16 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'FiltLoop' (firmware/nnet_utils/nnet_pooling_stream.h:147:9) in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>' completely with a factor of 16 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# WARNING: [HLS 214-189] Pipeline directive for loop 'FiltLoop' (firmware/nnet_utils/nnet_pooling_stream.h:147:9) in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>' has been removed because the loop is unrolled completely (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'PoolLoop' (firmware/nnet_utils/nnet_pooling_stream.h:152:13) in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config4>' completely with a factor of 4 (firmware/nnet_utils/nnet_pooling_stream.h:177:0)
# INFO: [HLS 214-186] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49:9) in function 'nnet::relu<nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, relu_config3>' completely with a factor of 16 (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-186] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:359:9) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' completely with a factor of 16 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelPushChannel' (firmware/nnet_utils/nnet_conv_stream.h:174:5) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' completely with a factor of 1 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' completely with a factor of 3 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# WARNING: [HLS 214-189] Pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' has been removed because the loop is unrolled completely (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:164:9) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>' completely with a factor of 1 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 4 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 4 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 16 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_22_1' (firmware/nnet_utils/nnet_padding_stream.h:22:22) in function 'nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config8>' completely with a factor of 1 (firmware/nnet_utils/nnet_padding_stream.h:30:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config8>(hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:30:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_uint<1> >::value), ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(config2_mult::accum_t)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2_mult::weight_t*, config2_mult::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long) const' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config2>(nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long)' into 'void nnet::relu<nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, relu_config3>(hls::stream<nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long)' into 'void nnet::relu<nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, relu_config3>(hls::stream<nnet::array<ap_fixed<27, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_uint<1> >::value), ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>(config6::accum_t)' into 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>*, config6::weight_t*, config6::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long)' into 'void nnet::sigmoid<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, sigmoid_config7>(hls::stream<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:65:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long)' into 'void nnet::sigmoid<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, sigmoid_config7>(hls::stream<nnet::array<ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:65:0)
# INFO: [HLS 214-248] Applying array_partition to 'b2': Complete partitioning on dimension 1. (firmware/weights/b2.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to 'b6': Complete partitioning on dimension 1. (firmware/weights/b6.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to '_ZZN4nnet22compute_pool_buffer_1dINS_5arrayI8ap_fixedILi16ELi6EL9ap_q_mode5EL9ap_o_mode3ELi0EELj16EEES6_7config4EEvRKT_RN3hls6streamIT0_Li0EEEE11kernel_data': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_pooling_stream.h:134:0)
# INFO: [HLS 214-248] Applying array_partition to '_ZZN4nnet24compute_output_buffer_1dINS_5arrayI8ap_fixedILi16ELi6EL9ap_q_mode5EL9ap_o_mode3ELi0EELj1EEENS1_IS2_ILi27ELi13ELS3_5ELS4_3ELi0EELj16EEE7config2EEvRKT_RN3hls6streamIT0_Li0EEEPNT1_8weight_tEPNSI_6bias_tEE11kernel_data': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_conv_stream.h:337:0)
# INFO: [HLS 214-248] Applying array_partition to 'res_out': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_conv_stream.h:340:29)
# INFO: [HLS 214-248] Applying array_partition to 'mult': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_latency.h:17:32)
# INFO: [HLS 214-248] Applying array_partition to 'data': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_stream.h:87:30)
# INFO: [HLS 214-248] Applying array_partition to 'res': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_stream.h:90:29)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer6_out' with compact=bit mode in 37-bits (firmware/myproject.cpp:49:34)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer4_out' with compact=bit mode in 256-bits (firmware/myproject.cpp:44:27)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer3_out' with compact=bit mode in 256-bits (firmware/myproject.cpp:40:27)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer2_out' with compact=bit mode in 432-bits (firmware/myproject.cpp:36:34)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer8_out' with compact=bit mode in 16-bits (firmware/myproject.cpp:32:24)
# INFO: [HLS 214-364] Automatically inlining function 'void nnet::dense_latency<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>*, config6::weight_t*, config6::bias_t*)' to improve effectiveness of pipeline pragma in function 'void nnet::dense_latency_wrapper<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>, config6>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<37, 23, (ap_q_mode)5, (ap_o_mode)3, 0>*, config6::weight_t*, config6::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:17:2)
# INFO: [HLS 214-376] automatically set the pipeline for Loop< CopyMain> at firmware/nnet_utils/nnet_padding_stream.h:37:5
# INFO: [HLS 214-376] automatically set the pipeline for Loop< PadRight> at firmware/nnet_utils/nnet_padding_stream.h:42:5
# INFO: [HLS 200-111] Finished Compiling Optimization and Transform: CPU user time: 43.8 seconds. CPU system time: 0.78 seconds. Elapsed time: 48.56 seconds; current allocated memory: 365.801 MB.
# INFO: [HLS 200-111] Finished Checking Pragmas: CPU user time: 0 seconds. CPU system time: 0 seconds. Elapsed time: 0 seconds; current allocated memory: 365.801 MB.
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-111] Finished Standard Transforms: CPU user time: 0.75 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.75 seconds; current allocated memory: 384.949 MB.
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [HLS 200-111] Finished Checking Synthesizability: CPU user time: 0.6 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.61 seconds; current allocated memory: 408.148 MB.
# INFO: [XFORM 203-712] Applying dataflow to function 'myproject' (firmware/myproject.cpp:8), detected/extracted 6 process function(s):
# 	 'nnet::zeropad1d_cl<nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config8>'
# ...
# |32    |  start_for_conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_27_13_5_3_0_16u_config2cud_U    |myproject_start_for_conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_27_13_5_3_0_16u_config2cud                                                                                       |    11|
# |33    |  start_for_dense_array_ap_fixed_16u_array_ap_fixed_37_23_5_3_0_1u_config6_U0_U         |myproject_start_for_dense_array_ap_fixed_16u_array_ap_fixed_37_23_5_3_0_1u_config6_U0                                                                                            |    11|
# |34    |  start_for_pooling1d_cl_array_array_ap_fixed_16_6_5_3_0_16u_config4_U0_U               |myproject_start_for_pooling1d_cl_array_array_ap_fixed_16_6_5_3_0_16u_config4_U0                                                                                                  |    12|
# |35    |  start_for_relu_array_ap_fixed_16u_array_ap_fixed_16_6_5_3_0_16u_relu_config3_U0_U     |myproject_start_for_relu_array_ap_fixed_16u_array_ap_fixed_16_6_5_3_0_16u_relu_config3_U0                                                                                        |    11|
# |36    |  start_for_sigmoid_array_array_ap_fixed_16_6_5_3_0_1u_sigmoid_config7_U0_U             |myproject_start_for_sigmoid_array_array_ap_fixed_16_6_5_3_0_1u_sigmoid_config7_U0                                                                                                |     9|
# |37    |  zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config8_U0                |myproject_zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config8_s                                                                                                  |   158|
# |38    |    grp_zeropad1d_cl_array_array_ap_fixed_16_6_5_3_0_1u_config8_Pipeline_CopyMain_fu_38 |myproject_zeropad1d_cl_array_array_ap_fixed_16_6_5_3_0_1u_config8_Pipeline_CopyMain                                                                                              |    73|
# |39    |      flow_control_loop_pipe_sequential_init_U                                          |myproject_flow_control_loop_pipe_sequential_init_0                                                                                                                               |    30|
# |40    |    grp_zeropad1d_cl_array_array_ap_fixed_16_6_5_3_0_1u_config8_Pipeline_PadRight_fu_46 |myproject_zeropad1d_cl_array_array_ap_fixed_16_6_5_3_0_1u_config8_Pipeline_PadRight                                                                                              |    18|
# |41    |      flow_control_loop_pipe_sequential_init_U                                          |myproject_flow_control_loop_pipe_sequential_init                                                                                                                                 |    14|
# |42    |    regslice_both_conv1d_input_U                                                        |myproject_regslice_both                                                                                                                                                          |    57|
# +------+----------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# ---------------------------------------------------------------------------------
# Finished Writing Synthesis Report : Time (s): cpu = 00:00:31 ; elapsed = 00:00:47 . Memory (MB): peak = 3119.027 ; gain = 1769.016 ; free physical = 5522 ; free virtual = 16060
# ---------------------------------------------------------------------------------
# Synthesis finished with 0 errors, 0 critical warnings and 384 warnings.
# Synthesis Optimization Runtime : Time (s): cpu = 00:00:33 ; elapsed = 00:00:48 . Memory (MB): peak = 3122.938 ; gain = 1772.926 ; free physical = 14370 ; free virtual = 24907
# Synthesis Optimization Complete : Time (s): cpu = 00:00:33 ; elapsed = 00:00:48 . Memory (MB): peak = 3122.938 ; gain = 1772.926 ; free physical = 14370 ; free virtual = 24891
# INFO: [Project 1-571] Translating synthesized netlist
# Netlist sorting complete. Time (s): cpu = 00:00:00.37 ; elapsed = 00:00:00.37 . Memory (MB): peak = 3149.832 ; gain = 0.000 ; free physical = 14367 ; free virtual = 24888
# INFO: [Netlist 29-17] Analyzing 4097 Unisim elements for replacement
# INFO: [Netlist 29-28] Unisim Transformation completed in 0 CPU seconds
# INFO: [Project 1-570] Preparing netlist for logic optimization
# INFO: [Opt 31-138] Pushed 0 inverter(s) to 0 load pin(s).
# Netlist sorting complete. Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00 . Memory (MB): peak = 3341.949 ; gain = 0.000 ; free physical = 14273 ; free virtual = 24794
# INFO: [Project 1-111] Unisim Transformation Summary:
#   A total of 25 instances were transformed.
#   BUFG => BUFGCE: 1 instance
#   DSP48E2 => DSP48E2 (DSP_ALU, DSP_A_B_DATA, DSP_C_DATA, DSP_MULTIPLIER, DSP_M_DATA, DSP_OUTPUT, DSP_PREADD, DSP_PREADD_DATA): 3 instances
#   IBUF => IBUF (IBUFCTRL, INBUF): 21 instances
#
# Synth Design complete | Checksum: d1846b1a
# INFO: [Common 17-83] Releasing license: Synthesis
# 297 Infos, 114 Warnings, 0 Critical Warnings and 0 Errors encountered.
# synth_design completed successfully
# synth_design: Time (s): cpu = 00:00:40 ; elapsed = 00:00:55 . Memory (MB): peak = 3341.984 ; gain = 1992.004 ; free physical = 14271 ; free virtual = 24792
# INFO: [Common 17-2834] synth_design peak Physical Memory [PSS] (MB): overall = 11463.139; main = 2802.110; forked = 9227.372
# INFO: [Common 17-2834] synth_design peak Virtual Memory [VSS] (MB): overall = 16334.707; main = 3341.953; forked = 13256.059
# # opt_design -retarget -propconst -sweep -bram_power_opt -shift_register_opt
# Command: opt_design -retarget -propconst -sweep -bram_power_opt -shift_register_opt
# Attempting to get a license for feature 'Implementation' and/or device 'xcu250'
# INFO: [Common 17-349] Got license for feature 'Implementation' and/or device 'xcu250'
# Running DRC as a precondition to command opt_design
#
# Starting DRC Task
# INFO: [DRC 23-27] Running DRC with 8 threads
# INFO: [Project 1-461] DRC finished with 0 Errors
# INFO: [Project 1-462] Please refer to the DRC report (report_drc) for more information.
#
# Time (s): cpu = 00:00:01 ; elapsed = 00:00:00.53 . Memory (MB): peak = 3405.980 ; gain = 63.996 ; free physical = 14272 ; free virtual = 24793
#
# Starting Cache Timing Information Task
# INFO: [Timing 38-35] Done setting XDC timing constraints.
# Ending Cache Timing Information Task | Checksum: 1a9d4d481
#
# Time (s): cpu = 00:00:03 ; elapsed = 00:00:01 . Memory (MB): peak = 3495.371 ; gain = 89.391 ; free physical = 14242 ; free virtual = 24763
#
# Starting Logic Optimization Task
#
# Phase 1 Initialization
#
# Phase 1.1 Core Generation And Design Setup
# Phase 1.1 Core Generation And Design Setup | Checksum: 1a9d4d481
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14058 ; free virtual = 24579
#
# Phase 1.2 Setup Constraints And Sort Netlist
# Phase 1.2 Setup Constraints And Sort Netlist | Checksum: 1a9d4d481
#
# Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00.02 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14058 ; free virtual = 24579
# Phase 1 Initialization | Checksum: 1a9d4d481
#
# Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00.02 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14058 ; free virtual = 24579
#
# Phase 2 Timer Update And Timing Data Collection
#
# Phase 2.1 Timer Update
# Phase 2.1 Timer Update | Checksum: 1a9d4d481
#
# Time (s): cpu = 00:00:01 ; elapsed = 00:00:00.33 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14051 ; free virtual = 24572
#
# Phase 2.2 Timing Data Collection
# Phase 2.2 Timing Data Collection | Checksum: 1a9d4d481
#
# Time (s): cpu = 00:00:01 ; elapsed = 00:00:00.41 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14051 ; free virtual = 24572
# Phase 2 Timer Update And Timing Data Collection | Checksum: 1a9d4d481
#
# Time (s): cpu = 00:00:01 ; elapsed = 00:00:00.41 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14051 ; free virtual = 24572
#
# Phase 3 Retarget
# INFO: [Opt 31-1566] Pulled 4 inverters resulting in an inversion of 23 pins
# INFO: [Opt 31-138] Pushed 2 inverter(s) to 270 load pin(s).
# INFO: [Opt 31-49] Retargeted 0 cell(s).
# Phase 3 Retarget | Checksum: 1ad29ed80
#
# Time (s): cpu = 00:00:02 ; elapsed = 00:00:00.95 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14045 ; free virtual = 24566
# Retarget | Checksum: 1ad29ed80
# INFO: [Opt 31-389] Phase Retarget created 0 cells and removed 5 cells
#
# Phase 4 Constant propagation
# INFO: [Opt 31-138] Pushed 0 inverter(s) to 0 load pin(s).
# Phase 4 Constant propagation | Checksum: d05377a3
#
# Time (s): cpu = 00:00:02 ; elapsed = 00:00:01 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14041 ; free virtual = 24562
# Constant propagation | Checksum: d05377a3
# INFO: [Opt 31-389] Phase Constant propagation created 0 cells and removed 0 cells
#
# Phase 5 Sweep
# Phase 5 Sweep | Checksum: 11965960f
#
# Time (s): cpu = 00:00:03 ; elapsed = 00:00:02 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14039 ; free virtual = 24560
# Sweep | Checksum: 11965960f
# INFO: [Opt 31-389] Phase Sweep created 0 cells and removed 0 cells
#
# Phase 6 Shift Register Optimization
# INFO: [Opt 31-1064] SRL Remap converted 0 SRLs to 0 registers and converted 0 registers of register chains to 0 SRLs
# Phase 6 Shift Register Optimization | Checksum: 11965960f
#
# Time (s): cpu = 00:00:03 ; elapsed = 00:00:02 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14039 ; free virtual = 24560
# Shift Register Optimization | Checksum: 11965960f
# INFO: [Opt 31-389] Phase Shift Register Optimization created 0 cells and removed 0 cells
#
# Phase 7 Post Processing Netlist
# Phase 7 Post Processing Netlist | Checksum: 11965960f
#
# Time (s): cpu = 00:00:03 ; elapsed = 00:00:02 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14039 ; free virtual = 24560
# Post Processing Netlist | Checksum: 11965960f
# INFO: [Opt 31-389] Phase Post Processing Netlist created 0 cells and removed 0 cells
#
# Phase 8 Finalization
#
# Phase 8.1 Finalizing Design Cores and Updating Shapes
# Phase 8.1 Finalizing Design Cores and Updating Shapes | Checksum: 6b7d8d97
#
# Time (s): cpu = 00:00:04 ; elapsed = 00:00:03 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14056 ; free virtual = 24577
#
# Phase 8.2 Verifying Netlist Connectivity
# Phase 8.2 Verifying Netlist Connectivity | Checksum: 6b7d8d97
#
# Time (s): cpu = 00:00:04 ; elapsed = 00:00:03 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14056 ; free virtual = 24577
# Phase 8 Finalization | Checksum: 6b7d8d97
#
# Time (s): cpu = 00:00:04 ; elapsed = 00:00:03 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14056 ; free virtual = 24577
# Opt_design Change Summary
# =========================
#
#
# -------------------------------------------------------------------------------------------------------------------------
# |  Phase                        |  #Cells created  |  #Cells Removed  |  #Constrained objects preventing optimizations  |
# -------------------------------------------------------------------------------------------------------------------------
# |  Retarget                     |               0  |               5  |                                              0  |
# |  Constant propagation         |               0  |               0  |                                              0  |
# |  Sweep                        |               0  |               0  |                                              0  |
# |  Shift Register Optimization  |               0  |               0  |                                              0  |
# |  Post Processing Netlist      |               0  |               0  |                                              0  |
# -------------------------------------------------------------------------------------------------------------------------
#
#
# Ending Logic Optimization Task | Checksum: 6b7d8d97
#
# Time (s): cpu = 00:00:04 ; elapsed = 00:00:03 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14056 ; free virtual = 24577
# INFO: [Constraints 18-11670] Building netlist checker database with flags, 0x8
# Done building netlist checker database: Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00 . Memory (MB): peak = 3676.355 ; gain = 0.000 ; free physical = 14056 ; free virtual = 24577
#
# Starting Power Optimization Task
# INFO: [Pwropt 34-132] Skipping clock gating for clocks with a period < 2.00 ns.
# INFO: [Pwropt 34-9] Applying IDT optimizations ...
# INFO: [Pwropt 34-10] Applying ODC optimizations ...
# INFO: [Timing 38-35] Done setting XDC timing constraints.
# WARNING: [Power 33-232] No user defined clocks were found in the design! Power estimation will be inaccurate until this is corrected.
# Resolution: Please specify clocks using create_clock/create_generated_clock for sequential elements. For pure combinatorial circuits, please specify a virtual clock, otherwise the vectorless estimation might be inaccurate
# Running Vector-less Activity Propagation...
#
# Finished Running Vector-less Activity Propagation
#
#
# Starting PowerOpt Patch Enables Task
# INFO: [Pwropt 34-162] WRITE_MODE attribute of 0 BRAM(s) out of a total of 26 has been updated to save power. Run report_power_opt to get a complete listing of the BRAMs updated.
# INFO: [Pwropt 34-201] Structural ODC has moved 21 WE to EN ports
# Number of BRAM Ports augmented: 0 newly gated: 25 Total Ports: 52
# Ending PowerOpt Patch Enables Task | Checksum: 11530e256
#
# Time (s): cpu = 00:00:00.15 ; elapsed = 00:00:00.16 . Memory (MB): peak = 4144.691 ; gain = 0.000 ; free physical = 13734 ; free virtual = 24255
# Ending Power Optimization Task | Checksum: 11530e256
#
# Time (s): cpu = 00:00:16 ; elapsed = 00:00:08 . Memory (MB): peak = 4144.691 ; gain = 468.336 ; free physical = 13734 ; free virtual = 24255
#
# Starting Final Cleanup Task
# Ending Final Cleanup Task | Checksum: 11530e256
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 4144.691 ; gain = 0.000 ; free physical = 13734 ; free virtual = 24255
#
# Starting Netlist Obfuscation Task
# Netlist sorting complete. Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00 . Memory (MB): peak = 4144.691 ; gain = 0.000 ; free physical = 13734 ; free virtual = 24255
# Ending Netlist Obfuscation Task | Checksum: 90cc5f93
#
# Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00.01 . Memory (MB): peak = 4144.691 ; gain = 0.000 ; free physical = 13734 ; free virtual = 24255
# INFO: [Common 17-83] Releasing license: Implementation
# 23 Infos, 1 Warnings, 0 Critical Warnings and 0 Errors encountered.
# opt_design completed successfully
# opt_design: Time (s): cpu = 00:00:26 ; elapsed = 00:00:14 . Memory (MB): peak = 4144.691 ; gain = 802.707 ; free physical = 13734 ; free virtual = 24255
# # report_utilization -file vivado_synth.rpt
# INFO: [Common 17-206] Exiting Vivado at Sat Jul 19 13:49:50 2025...
# ***** VIVADO SYNTHESIS COMPLETED IN 0h1m24s *****
# INFO: [HLS 200-112] Total CPU user time: 157.42 seconds. Total CPU system time: 4.5 seconds. Total elapsed time: 185.88 seconds; peak allocated memory: 1.063 GB.
# INFO: [Common 17-206] Exiting vitis_hls at Sat Jul 19 13:50:01 2025...
# Cosim report not found.
# Timing report not found.
# {'CSynthesisReport': {'TargetClockPeriod': '5.00',
#   'EstimatedClockPeriod': '3.581',
#   'BestLatency': '1457',
#   'WorstLatency': '1457',
#   'IntervalMin': '1450',
#   'IntervalMax': '1450',
#   'BRAM_18K': '33',
#   'DSP': '4',
#   'FF': '48303',
#   'LUT': '51740',
#   'URAM': '0',
#   'AvailableBRAM_18K': '5376',
#   'AvailableDSP': '12288',
#   'AvailableFF': '3456000',
#   'AvailableLUT': '1728000',
#   'AvailableURAM': '1280'},
#  'VivadoSynthReport': {'LUT': '31564',
#   'FF': '44710',
#   'BRAM_18K': '24.5',
#   'URAM': '0',
#   'DSP48E': '3'}}

# %% [markdown]
# ## Check the reports

# %%
hls4ml.report.read_vivado_report('hls4ml/Model4_prune_8b/')
# Out:
# Found 1 solution(s) in hls4ml/Model4_prune_8b//myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vitis HLS Report for 'myproject'
# ================================================================
# * Date:           Sat Jul 19 13:48:17 2025
#
# * Version:        2023.2 (Build 4023990 on Oct 11 2023)
# * Project:        myproject_prj
# * Solution:       solution1 (Vivado IP Flow Target)
# * Product family: virtexuplus
# * Target device:  xcu250-figd2104-2L-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  |  5.00 ns|  3.581 ns|     1.35 ns|
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+----------+----------+------+------+----------+
#     |  Latency (cycles) |  Latency (absolute) |   Interval  | Pipeline |
#     |   min   |   max   |    min   |    max   |  min |  max |   Type   |
#     +---------+---------+----------+----------+------+------+----------+
#     |     1457|     1457|  7.285 us|  7.285 us|  1450|  1450|  dataflow|
#     +---------+---------+----------+----------+------+------+----------+
#
#     + Detail:
#         * Instance:
#         +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+---------+
#         |                                                                        |                                                                       |  Latency (cycles) |   Latency (absolute)  |   Interval  | Pipeline|
#         |                                Instance                                |                                 Module                                |   min   |   max   |    min    |    max    |  min |  max |   Type  |
#         +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+---------+
#         |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config8_U0  |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config8_s  |      731|      731|   3.655 us|   3.655 us|   731|   731|       no|
#         |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_27_13_5_3_0_16u_config2_U0  |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_27_13_5_3_0_16u_config2_s  |     1449|     1449|   7.245 us|   7.245 us|  1449|  1449|       no|
#         |relu_array_ap_fixed_16u_array_ap_fixed_16_6_5_3_0_16u_relu_config3_U0   |relu_array_ap_fixed_16u_array_ap_fixed_16_6_5_3_0_16u_relu_config3_s   |      722|      722|   3.610 us|   3.610 us|   722|   722|       no|
#         |pooling1d_cl_array_array_ap_fixed_16_6_5_3_0_16u_config4_U0             |pooling1d_cl_array_array_ap_fixed_16_6_5_3_0_16u_config4_s             |      723|      723|   3.615 us|   3.615 us|   723|   723|       no|
#         |dense_array_ap_fixed_16u_array_ap_fixed_37_23_5_3_0_1u_config6_U0       |dense_array_ap_fixed_16u_array_ap_fixed_37_23_5_3_0_1u_config6_s       |      192|      192|   0.960 us|   0.960 us|   192|   192|       no|
#         |sigmoid_array_array_ap_fixed_16_6_5_3_0_1u_sigmoid_config7_U0           |sigmoid_array_array_ap_fixed_16_6_5_3_0_1u_sigmoid_config7_s           |        3|        3|  15.000 ns|  15.000 ns|     3|     3|       no|
#         +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+---------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +---------------------+---------+-------+---------+---------+------+
# |         Name        | BRAM_18K|  DSP  |    FF   |   LUT   | URAM |
# +---------------------+---------+-------+---------+---------+------+
# |DSP                  |        -|      -|        -|        -|     -|
# |Expression           |        -|      -|        0|        2|     -|
# |FIFO                 |       32|      -|     2336|     1284|     -|
# |Instance             |        1|      4|    45967|    50454|     -|
# |Memory               |        -|      -|        -|        -|     -|
# |Multiplexer          |        -|      -|        -|        -|     -|
# |Register             |        -|      -|        -|        -|     -|
# +---------------------+---------+-------+---------+---------+------+
# |Total                |       33|      4|    48303|    51740|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available SLR        |     1344|   3072|   864000|   432000|   320|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization SLR (%)  |        2|     ~0|        5|       11|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available            |     5376|  12288|  3456000|  1728000|  1280|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization (%)      |       ~0|     ~0|        1|        2|     0|
# +---------------------+---------+-------+---------+---------+------+
#
# + Detail:
#     * Instance:
#     +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+----+-------+-------+-----+
#     |                                Instance                                |                                 Module                                | BRAM_18K| DSP|   FF  |  LUT  | URAM|
#     +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+----+-------+-------+-----+
#     |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_27_13_5_3_0_16u_config2_U0  |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_27_13_5_3_0_16u_config2_s  |        0|   0|    588|   1539|    0|
#     |dense_array_ap_fixed_16u_array_ap_fixed_37_23_5_3_0_1u_config6_U0       |dense_array_ap_fixed_16u_array_ap_fixed_37_23_5_3_0_1u_config6_s       |        0|   4|  42832|  44667|    0|
#     |pooling1d_cl_array_array_ap_fixed_16_6_5_3_0_16u_config4_U0             |pooling1d_cl_array_array_ap_fixed_16_6_5_3_0_16u_config4_s             |        0|   0|   2422|   2763|    0|
#     |relu_array_ap_fixed_16u_array_ap_fixed_16_6_5_3_0_16u_relu_config3_U0   |relu_array_ap_fixed_16u_array_ap_fixed_16_6_5_3_0_16u_relu_config3_s   |        0|   0|     14|    905|    0|
#     |sigmoid_array_array_ap_fixed_16_6_5_3_0_1u_sigmoid_config7_U0           |sigmoid_array_array_ap_fixed_16_6_5_3_0_1u_sigmoid_config7_s           |        1|   0|     67|    309|    0|
#     |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config8_U0  |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_16_6_5_3_0_1u_config8_s  |        0|   0|     44|    271|    0|
#     +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+----+-------+-------+-----+
#     |Total                                                                   |                                                                       |        1|   4|  45967|  50454|    0|
#     +------------------------------------------------------------------------+-----------------------------------------------------------------------+---------+----+-------+-------+-----+
#
#     * DSP:
#     N/A
#
#     * Memory:
#     N/A
#
#     * FIFO:
#     +--------------+---------+------+----+-----+------+-----+---------+
#     |     Name     | BRAM_18K|  FF  | LUT| URAM| Depth| Bits| Size:D*B|
#     +--------------+---------+------+----+-----+------+-----+---------+
#     |layer2_out_U  |       15|  1056|   0|    -|   720|  432|   311040|
#     |layer3_out_U  |        8|   543|   0|    -|   720|  256|   184320|
#     |layer4_out_U  |        8|   541|   0|    -|   180|  256|    46080|
#     |layer6_out_U  |        0|   133|   0|    -|     1|   37|       37|
#     |layer8_out_U  |        1|    63|   0|    -|   723|   16|    11568|
#     +--------------+---------+------+----+-----+------+-----+---------+
#     |Total         |       32|  2336|   0|    0|  2344|  997|   553045|
#     +--------------+---------+------+----+-----+------+-----+---------+
#
#     * Expression:
#     +--------------+----------+----+---+----+------------+------------+
#     | Variable Name| Operation| DSP| FF| LUT| Bitwidth P0| Bitwidth P1|
#     +--------------+----------+----+---+----+------------+------------+
#     |ap_idle       |       and|   0|  0|   2|           1|           1|
#     +--------------+----------+----+---+----+------------+------------+
#     |Total         |          |   0|  0|   2|           1|           1|
#     +--------------+----------+----+---+----+------------+------------+
#
#     * Multiplexer:
#     N/A
#
#     * Register:
#     N/A
#
#
#
# ================================================================
# == Interface
# ================================================================
# * Summary:
# +---------------------+-----+-----+------------+--------------+--------------+
# |      RTL Ports      | Dir | Bits|  Protocol  | Source Object|    C Type    |
# +---------------------+-----+-----+------------+--------------+--------------+
# |conv1d_input_TDATA   |   in|   16|        axis|  conv1d_input|       pointer|
# |conv1d_input_TVALID  |   in|    1|        axis|  conv1d_input|       pointer|
# |conv1d_input_TREADY  |  out|    1|        axis|  conv1d_input|       pointer|
# |layer7_out_TDATA     |  out|   16|        axis|    layer7_out|       pointer|
# |layer7_out_TVALID    |  out|    1|        axis|    layer7_out|       pointer|
# |layer7_out_TREADY    |   in|    1|        axis|    layer7_out|       pointer|
# |ap_clk               |   in|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_rst_n             |   in|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_start             |   in|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_done              |  out|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_ready             |  out|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_idle              |  out|    1|  ap_ctrl_hs|     myproject|  return value|
# +---------------------+-----+-----+------------+--------------+--------------+
#
# Co-simulation report not found.
