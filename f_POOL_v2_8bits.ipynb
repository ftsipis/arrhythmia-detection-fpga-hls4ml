# %% [markdown]
# # Detecting arrythmia using Deep Leaning

# %% [markdown]
# ## Loading modules

# %%
import pandas as pd
import numpy as np
import wfdb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, TimeDistributed
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Download Dataset

# %%
from pathlib import Path
import zipfile

database_filename = "mit-bih-arrhythmia-database-1.0.0.zip"
expected_file = Path("mit-bih-arrhythmia-database-1.0.0")

if not expected_file.exists():
    with zipfile.ZipFile(database_filename, 'r') as zip_ref:
        zip_ref.extractall(".")
    print("Extraction complete.")
else:
    print("Files already extracted.")
# Out:
# Files already extracted.

# %% [markdown]
# ## Loading data

# %% [markdown]
# Loading list of records available, from dataset available [here](https://physionet.org/content/mitdb/1.0.0/)

# %%
records = np.loadtxt("mit-bih-arrhythmia-database-1.0.0/RECORDS", dtype=int)

# %% [markdown]
# Defining invalid beats as well as abnormal beats, according to [Physiobank](https://archive.physionet.org/physiobank/annotations.shtml)

# %%
invalid_beat = [
    "[", "!", "]", "x", "(", ")", "p", "t", 
    "u", "`", "'", "^", "|", "~", "+", "s", 
    "T", "*", "D", "=", '"', "@"
]

abnormal_beats = [
    "L", "R", "B", "A", "a", "J", "S", "V", 
    "r", "F", "e", "j", "n", "E", "/", "f", "Q", "?"
]

# %% [markdown]
# ## Processing dataset

# %% [markdown]
# This function classify a beat according to its symbol and the list provided above.

# %%
def classify_beat(symbol):
    if symbol in abnormal_beats:
        return 1
    elif symbol == "N" or symbol == ".":
        return 0

# %% [markdown]
# Given a signal, the beat location, and the window to be used as a sequence, this function gets the sequence. It will return an empty array in case of an invalid beat or empty sequence.

# %%
def get_sequence(signal, beat_loc, window_sec, fs):
    window_one_side = window_sec * fs
    beat_start = beat_loc - window_one_side
    beat_end = beat_loc + window_one_side
    if beat_end < signal.shape[0]:
        sequence = signal[beat_start:beat_end, 0]
        return sequence.reshape(1, -1, 1)
    else:
        return np.array([])

# %% [markdown]
# The code below will build a list of labels and sequences as well as map the sequences for each patient. The percentage calculated represents the ratio of abnormal beats in each patient data.

# %%
all_sequences = []
all_labels = []
window_sec = 3
subject_map = []
for subject in records:
    record = wfdb.rdrecord(f'mit-bih-arrhythmia-database-1.0.0/{subject}')
    annotation = wfdb.rdann(f'mit-bih-arrhythmia-database-1.0.0/{subject}', 'atr')
    atr_symbol = annotation.symbol
    atr_sample = annotation.sample
    fs = record.fs
    scaler = StandardScaler()
    signal = scaler.fit_transform(record.p_signal)
    subject_labels = []
    for i, i_sample in enumerate(atr_sample):
        label = classify_beat(atr_symbol[i])
        sequence = get_sequence(signal, i_sample, window_sec, fs)
        if label is not None and sequence.size > 0:
            all_sequences.append(sequence)
            subject_labels.append(label)

    normal_percentage = sum(subject_labels) / len(subject_labels)
    subject_map.append({
        "subject": subject,
        "percentage": normal_percentage,
        "num_seq": len(subject_labels),
        "start": len(all_labels),
        "end": len(all_labels)+len(subject_labels)
    })
    all_labels.extend(subject_labels)

# %%
print(subject_map[:5])
# Out:
# [{'subject': 100, 'percentage': 0.014977973568281937, 'num_seq': 2270, 'start': 0, 'end': 2270}, {'subject': 101, 'percentage': 0.0026838432635534087, 'num_seq': 1863, 'start': 2270, 'end': 4133}, {'subject': 102, 'percentage': 0.9546910755148741, 'num_seq': 2185, 'start': 4133, 'end': 6318}, {'subject': 103, 'percentage': 0.0009606147934678194, 'num_seq': 2082, 'start': 6318, 'end': 8400}, {'subject': 104, 'percentage': 0.926774483378257, 'num_seq': 2226, 'start': 8400, 'end': 10626}]

# %% [markdown]
# Creating bins to be used to stratify the train and validation split.

# %%
subject_map = pd.DataFrame(subject_map)

# %%
print(subject_map[:5])
# Out:
#    subject  percentage  num_seq  start    end
# 0      100    0.014978     2270      0   2270
# 1      101    0.002684     1863   2270   4133
# 2      102    0.954691     2185   4133   6318
# 3      103    0.000961     2082   6318   8400
# 4      104    0.926774     2226   8400  10626

# %% [markdown]
# The code presented will create class in each patient is segmented.

# %%
bins = [0, 0.2, 0.6, 1.0]
subject_map["bin"] = pd.cut(subject_map['percentage'], bins=bins, labels=False, include_lowest=True)

# %%
print(subject_map[:5])
# Out:
#    subject  percentage  num_seq  start    end  bin
# 0      100    0.014978     2270      0   2270    0
# 1      101    0.002684     1863   2270   4133    0
# 2      102    0.954691     2185   4133   6318    2
# 3      103    0.000961     2082   6318   8400    0
# 4      104    0.926774     2226   8400  10626    2

# %% [markdown]
# Now, the dataset is split into train and validation, stratifying by the bin defined above.

# %%
train, validation = train_test_split(subject_map, test_size=0.25, stratify=subject_map["bin"], random_state=42)

# %% [markdown]
# This function build a dataset based on the map for each split.

# %%
def build_dataset(df, all_sequences, all_labels):
    sequences = []
    labels = []
    for i, row in df.iterrows():
        start = int(row["start"])
        end = int(row["end"])
        sequences.extend(all_sequences[start:end])
        labels.extend(all_labels[start:end])
        
    return np.vstack(sequences), np.vstack(labels)

# %%
X_train, y_train = build_dataset(train, all_sequences, all_labels)
X_val, y_val = build_dataset(validation, all_sequences, all_labels)

# %%
X_train.shape, y_train.shape
# Out:
# ((83059, 720, 1), (83059, 1))

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### CNN model

# %%
from tensorflow.keras.layers import Input, BatchNormalization, Conv1D, MaxPooling1D, Activation, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.optimizers import Adam

sequence_size = X_train.shape[1]
n_features = 1

input_shape = (sequence_size, n_features)

filters_per_conv_layer = [8, 16, 32]
neurons_per_dense_layer = [32, 16]


x_in = Input(shape=input_shape, name="input_1")

x = x_in
for i, f in enumerate(filters_per_conv_layer):
    print(f'Adding convolutional block {i} with N={f} filters')
    x = Conv1D(
        filters=f,
        kernel_size=3,
        strides=1,
        padding='same',
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
        use_bias=False,
        name=f'conv_{i}'
    )(x)
    x = BatchNormalization(name=f'bn_conv_{i}')(x)
    x = Activation('relu', name=f'conv_act_{i}')(x)
    x = MaxPooling1D(pool_size=2, name=f'pool_{i}')(x)

x = GlobalMaxPooling1D(name="GlobalPool")(x)

for i, n in enumerate(neurons_per_dense_layer):
    print(f'Adding dense block {i} with N={n} neurons')
    x = Dense(
        n,
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
        use_bias=False,
        name=f'dense_{i}'
    )(x)
    x = BatchNormalization(name=f'bn_dense_{i}')(x)
    x = Activation('relu', name=f'dense_act_{i}')(x)
    x = Dropout(0.5)(x)

# Για binary classification
x = Dense(1, name='output_dense')(x)
x_out = Activation('sigmoid', name='output_sigmoid')(x)

cnn_model = Model(inputs=x_in, outputs=x_out, name='keras_cnn_1d_hls4ml')

optimizer = Adam(learning_rate=0.001)
cnn_model.compile(
    optimizer=optimizer,
    loss="binary_crossentropy",
    metrics=["accuracy"]
)


cnn_model.summary()
# Out:
# Adding convolutional block 0 with N=8 filters
# Adding convolutional block 1 with N=16 filters
# Adding convolutional block 2 with N=32 filters
# Adding dense block 0 with N=32 neurons
# Adding dense block 1 with N=16 neurons
# Model: "keras_cnn_1d_hls4ml"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 720, 1)]          0
#
#  conv_0 (Conv1D)             (None, 720, 8)            24
#
#  bn_conv_0 (BatchNormalizat  (None, 720, 8)            32
#  ion)
#
#  conv_act_0 (Activation)     (None, 720, 8)            0
#
#  pool_0 (MaxPooling1D)       (None, 360, 8)            0
#
#  conv_1 (Conv1D)             (None, 360, 16)           384
#
#  bn_conv_1 (BatchNormalizat  (None, 360, 16)           64
#  ion)
#
#  conv_act_1 (Activation)     (None, 360, 16)           0
#
#  pool_1 (MaxPooling1D)       (None, 180, 16)           0
#
#  conv_2 (Conv1D)             (None, 180, 32)           1536
#
#  bn_conv_2 (BatchNormalizat  (None, 180, 32)           128
#  ion)
#
#  conv_act_2 (Activation)     (None, 180, 32)           0
#
#  pool_2 (MaxPooling1D)       (None, 90, 32)            0
#
#  GlobalPool (GlobalMaxPooli  (None, 32)                0
#  ng1D)
#
#  dense_0 (Dense)             (None, 32)                1024
#
#  bn_dense_0 (BatchNormaliza  (None, 32)                128
#  tion)
#
#  dense_act_0 (Activation)    (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                512
#
#  bn_dense_1 (BatchNormaliza  (None, 16)                64
#  tion)
#
#  dense_act_1 (Activation)    (None, 16)                0
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  output_dense (Dense)        (None, 1)                 17
#
#  output_sigmoid (Activation  (None, 1)                 0
#  )
#
# =================================================================
# Total params: 3913 (15.29 KB)
# Trainable params: 3705 (14.47 KB)
# Non-trainable params: 208 (832.00 Byte)
# _________________________________________________________________

# %%
import json
from tensorflow.keras.models import load_model

train = False
if train:
    hist_cnn = cnn_model.fit(
        X_train, 
        y_train, 
        batch_size=128,
        epochs=15,
        validation_data=(X_val, y_val)
    )
    cnn_model.save('Model3/cnn_model.keras')

    with open('Model3/hist_cnn.json', 'w') as f:
        json.dump(hist_cnn.history, f)

    with open('Model3/hist_cnn.json', 'r') as f:
        hist_cnn = json.load(f)
else:
    cnn_model = load_model('Model3/cnn_model.keras')

    with open('Model3/hist_cnn.json', 'r') as f:
        hist_cnn = json.load(f)

# %%
cnn_model.evaluate(X_val, y_val)
# Out:
# 823/823 [==============================] - 1s 1ms/step - loss: 0.7941 - accuracy: 0.7945
# [0.7940711379051208, 0.794489860534668]

# %%
# summarize history for accuracy
plt.plot(hist_cnn['accuracy'])
plt.plot(hist_cnn['val_accuracy'])
plt.title('CNN model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist_cnn['loss'])
plt.plot(hist_cnn['val_loss'])
plt.title('CNN model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Make an hls4ml config & model

# %%
import hls4ml
import plotting 

os.environ['PATH'] = os.environ['XILINX_VITIS'] + '/bin:' + os.environ['PATH']

config = hls4ml.utils.config_from_keras_model(cnn_model, granularity='name', backend='Vitis')
config['Model']['Precision'] = 'ap_fixed<8,4>'
print("-----------------------------------")
print("Configuration")
plotting.print_dict(config)
print("-----------------------------------")

hls_model = hls4ml.converters.convert_from_keras_model(cnn_model, hls_config=config, backend='Vitis', output_dir='hls4ml/f_model_3_8b', part='xcu250-figd2104-2L-e', io_type='io_stream')
# Out:
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 720, 1]], output shape: [None, 720, 1]
# Layer name: conv_0, layer type: Conv1D, input shapes: [[None, 720, 1]], output shape: [None, 720, 8]
# Layer name: bn_conv_0, layer type: BatchNormalization, input shapes: [[None, 720, 8]], output shape: [None, 720, 8]
# Layer name: conv_act_0, layer type: Activation, input shapes: [[None, 720, 8]], output shape: [None, 720, 8]
# Layer name: pool_0, layer type: MaxPooling1D, input shapes: [[None, 720, 8]], output shape: [None, 360, 8]
# Layer name: conv_1, layer type: Conv1D, input shapes: [[None, 360, 8]], output shape: [None, 360, 16]
# Layer name: bn_conv_1, layer type: BatchNormalization, input shapes: [[None, 360, 16]], output shape: [None, 360, 16]
# Layer name: conv_act_1, layer type: Activation, input shapes: [[None, 360, 16]], output shape: [None, 360, 16]
# Layer name: pool_1, layer type: MaxPooling1D, input shapes: [[None, 360, 16]], output shape: [None, 180, 16]
# Layer name: conv_2, layer type: Conv1D, input shapes: [[None, 180, 16]], output shape: [None, 180, 32]
# Layer name: bn_conv_2, layer type: BatchNormalization, input shapes: [[None, 180, 32]], output shape: [None, 180, 32]
# Layer name: conv_act_2, layer type: Activation, input shapes: [[None, 180, 32]], output shape: [None, 180, 32]
# Layer name: pool_2, layer type: MaxPooling1D, input shapes: [[None, 180, 32]], output shape: [None, 90, 32]
# Layer name: GlobalPool, layer type: GlobalMaxPooling1D, input shapes: [[None, 90, 32]], output shape: [None, 32]
# Layer name: dense_0, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: bn_dense_0, layer type: BatchNormalization, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: dense_act_0, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 16]
# Layer name: bn_dense_1, layer type: BatchNormalization, input shapes: [[None, 16]], output shape: [None, 16]
# Layer name: dense_act_1, layer type: Activation, input shapes: [[None, 16]], output shape: [None, 16]
# Layer name: output_dense, layer type: Dense, input shapes: [[None, 16]], output shape: [None, 1]
# Layer name: output_sigmoid, layer type: Activation, input shapes: [[None, 1]], output shape: [None, 1]
# -----------------------------------
# Configuration
# Model
#   Precision:         ap_fixed<8,4>
#   ReuseFactor:       1
#   Strategy:          Latency
#   BramFactor:        1000000000
#   TraceOutput:       False
# LayerName
#   input_1
#     Trace:           False
#     Precision
#       result:        auto
#   conv_0
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#     ParallelizationFactor:1
#     ConvImplementation:LineBuffer
#   conv_0_linear
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   bn_conv_0
#     Trace:           False
#     Precision
#       result:        auto
#       scale:         auto
#       bias:          auto
#     ReuseFactor:     1
#   conv_act_0
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   pool_0
#     Trace:           False
#     Precision
#       result:        auto
#       accum:         auto
#     ReuseFactor:     1
#     ConvImplementation:LineBuffer
#   conv_1
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#     ParallelizationFactor:1
#     ConvImplementation:LineBuffer
#   conv_1_linear
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   bn_conv_1
#     Trace:           False
#     Precision
#       result:        auto
#       scale:         auto
#       bias:          auto
#     ReuseFactor:     1
#   conv_act_1
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   pool_1
#     Trace:           False
#     Precision
#       result:        auto
#       accum:         auto
#     ReuseFactor:     1
#     ConvImplementation:LineBuffer
#   conv_2
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#     ParallelizationFactor:1
#     ConvImplementation:LineBuffer
#   conv_2_linear
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   bn_conv_2
#     Trace:           False
#     Precision
#       result:        auto
#       scale:         auto
#       bias:          auto
#     ReuseFactor:     1
#   conv_act_2
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   pool_2
#     Trace:           False
#     Precision
#       result:        auto
#       accum:         auto
#     ReuseFactor:     1
#     ConvImplementation:LineBuffer
#   GlobalPool
#     Trace:           False
#     Precision
#       result:        auto
#       accum:         auto
#     ReuseFactor:     1
#   dense_0
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#   dense_0_linear
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   bn_dense_0
#     Trace:           False
#     Precision
#       result:        auto
#       scale:         auto
#       bias:          auto
#     ReuseFactor:     1
#   dense_act_0
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   dense_1
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#   dense_1_linear
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   bn_dense_1
#     Trace:           False
#     Precision
#       result:        auto
#       scale:         auto
#       bias:          auto
#     ReuseFactor:     1
#   dense_act_1
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   output_dense
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#   output_dense_linear
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   output_sigmoid
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
# -----------------------------------
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 720, 1]], output shape: [None, 720, 1]
# Layer name: conv_0, layer type: Conv1D, input shapes: [[None, 720, 1]], output shape: [None, 720, 8]
# Layer name: bn_conv_0, layer type: BatchNormalization, input shapes: [[None, 720, 8]], output shape: [None, 720, 8]
# Layer name: conv_act_0, layer type: Activation, input shapes: [[None, 720, 8]], output shape: [None, 720, 8]
# Layer name: pool_0, layer type: MaxPooling1D, input shapes: [[None, 720, 8]], output shape: [None, 360, 8]
# Layer name: conv_1, layer type: Conv1D, input shapes: [[None, 360, 8]], output shape: [None, 360, 16]
# Layer name: bn_conv_1, layer type: BatchNormalization, input shapes: [[None, 360, 16]], output shape: [None, 360, 16]
# Layer name: conv_act_1, layer type: Activation, input shapes: [[None, 360, 16]], output shape: [None, 360, 16]
# Layer name: pool_1, layer type: MaxPooling1D, input shapes: [[None, 360, 16]], output shape: [None, 180, 16]
# Layer name: conv_2, layer type: Conv1D, input shapes: [[None, 180, 16]], output shape: [None, 180, 32]
# Layer name: bn_conv_2, layer type: BatchNormalization, input shapes: [[None, 180, 32]], output shape: [None, 180, 32]
# Layer name: conv_act_2, layer type: Activation, input shapes: [[None, 180, 32]], output shape: [None, 180, 32]
# Layer name: pool_2, layer type: MaxPooling1D, input shapes: [[None, 180, 32]], output shape: [None, 90, 32]
# Layer name: GlobalPool, layer type: GlobalMaxPooling1D, input shapes: [[None, 90, 32]], output shape: [None, 32]
# Layer name: dense_0, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: bn_dense_0, layer type: BatchNormalization, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: dense_act_0, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: dense_1, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 16]
# Layer name: bn_dense_1, layer type: BatchNormalization, input shapes: [[None, 16]], output shape: [None, 16]
# Layer name: dense_act_1, layer type: Activation, input shapes: [[None, 16]], output shape: [None, 16]
# Layer name: output_dense, layer type: Dense, input shapes: [[None, 16]], output shape: [None, 1]
# Layer name: output_sigmoid, layer type: Activation, input shapes: [[None, 1]], output shape: [None, 1]
# Creating HLS model

# %% [markdown]
# ## Visualise the model architecture

# %%
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=None)

# %% [markdown]
# ## Compile, predict

# %%
hls_model.compile()
X_val = np.ascontiguousarray(X_val)
y_hls = hls_model.predict(X_val)
# Out:
# Writing HLS project
# Done

# %% [markdown]
# ## HLS4ML Model Accuracy

# %%
from sklearn.metrics import accuracy_score

# Convert predictions to binary labels using a threshold of 0.5
y_hls_pred   = (y_hls > 0.5).astype(int)

# Calculate accuracy using ground truth y_val
acc_hls   = accuracy_score(y_val, y_hls_pred)

print("HLS4ML Model Accuracy: {:.2f}%".format(acc_hls * 100))
# Out:
# HLS4ML Model Accuracy: 67.92%

# %% [markdown]
# ## Synthesize

# %%
hls_model.build(csim=False, synth=True, vsynth=True, export=True)
# Out:
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2023.2 (64-bit)
#   **** SW Build 4023990 on Oct 11 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis_HLS/2023.2/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vitis_HLS/2023.2/bin/unwrapped/lnx64.o/vitis_hls'
# INFO: [HLS 200-10] For user 'fotis' on host 'fotis-Z390-UD' (Linux_x86_64 version 6.8.0-64-generic) on Sat Jul 19 16:58:25 EEST 2025
# INFO: [HLS 200-10] On os Ubuntu 24.04.2 LTS
# INFO: [HLS 200-10] In directory '/home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b'
# INFO: [HLS 200-2053] The vitis_hls executable is being deprecated. Consider using vitis-run --mode hls --tcl
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-1510] Running: open_project myproject_prj
# INFO: [HLS 200-10] Creating and opening project '/home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj'.
# INFO: [HLS 200-1510] Running: set_top myproject
# INFO: [HLS 200-1510] Running: add_files firmware/myproject.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb myproject_test.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb firmware/weights
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-1510] Running: add_files -tb tb_data
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-1510] Running: open_solution solution1
# INFO: [HLS 200-10] Creating and opening solution '/home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1510] Running: config_array_partition -maximum_size 4096
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# ERROR: [HLS 200-642] The 'config_array_partition -maximum_size' command is not supported.
# INFO: [HLS 200-1510] Running: config_compile -name_max_length 80
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: set_part xcu250-figd2104-2L-e
# INFO: [HLS 200-1611] Setting target device to 'xcu250-figd2104-2L-e'
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: config_schedule -enable_dsp_full_reg=false
# INFO: [HLS 200-1510] Running: create_clock -period 5 -name default
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [HLS 200-1510] Running: set_clock_uncertainty 27% default
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 1.35ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [HLS 200-1510] Running: csynth_design
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 0.03 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.03 seconds; current allocated memory: 256.426 MB.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:33:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:107:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:189:9)
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:46:81)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:46:85)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:62:81)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:62:85)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:78:83)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:78:88)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:94:79)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:94:84)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:102:79)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:102:84)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:110:84)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:110:89)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 200-471] Dataflow form checks found 12 issue(s) in file firmware/myproject.cpp
# Resolution: For help on HLS 200-471 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-471.html
# WARNING: [HLS 207-5292] unused parameter 'keep' (firmware/nnet_utils/nnet_helpers.h:285:99)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:14:36)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:15:36)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:16:44)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:24:24)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:25:24)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:26:32)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:33:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:33:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:34:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:35:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:42:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:42:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:43:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:44:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:51:29)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:51:80)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:52:50)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:53:48)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:16:39)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_code_gen.h:17:38)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_code_gen.h:18:60)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_code_gen.h:19:58)
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 4.73 seconds. CPU system time: 0.39 seconds. Elapsed time: 5.14 seconds; current allocated memory: 264.965 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# INFO: [HLS 200-1995] There were 11,040 instructions in the design after the 'Compile/Link' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# WARNING: [HLS 200-1995] There were 227,697 instructions in the design after the 'Unroll/Inline (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 64,046 instructions in the design after the 'Unroll/Inline (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 63,226 instructions in the design after the 'Unroll/Inline (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 60,364 instructions in the design after the 'Unroll/Inline (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 40,307 instructions in the design after the 'Array/Struct (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 24,338 instructions in the design after the 'Array/Struct (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 24,380 instructions in the design after the 'Array/Struct (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 28,715 instructions in the design after the 'Array/Struct (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 28,811 instructions in the design after the 'Array/Struct (step 5)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 28,463 instructions in the design after the 'Performance' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 28,448 instructions in the design after the 'Performance (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 28,486 instructions in the design after the 'Performance (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 28,486 instructions in the design after the 'Performance (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 27,563 instructions in the design after the 'HW Transforms (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 27,991 instructions in the design after the 'HW Transforms (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_model_3_8b/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>' (firmware/nnet_utils/nnet_pooling_stream.h:182:9)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config11>' (firmware/nnet_utils/nnet_pooling_stream.h:182:9)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config16>' (firmware/nnet_utils/nnet_pooling_stream.h:182:9)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config18>' (firmware/nnet_utils/nnet_dense_stream.h:85:9)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>*, config18::weight_t*, config18::bias_t*)', Pragma conflict happens on 'INLINE' and 'PIPELINE' pragmas: same function (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config22>' (firmware/nnet_utils/nnet_dense_stream.h:85:9)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, config22>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>*, config22::weight_t*, config22::bias_t*)', Pragma conflict happens on 'INLINE' and 'PIPELINE' pragmas: same function (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<21, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config26>' (firmware/nnet_utils/nnet_dense_stream.h:85:9)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<21, 13, (ap_q_mode)5, (ap_o_mode)3, 0>, config26>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<21, 13, (ap_q_mode)5, (ap_o_mode)3, 0>*, config26::weight_t*, config26::bias_t*)', Pragma conflict happens on 'INLINE' and 'PIPELINE' pragmas: same function (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config29>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config29>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:33:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_data<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config29>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config29>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:38:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config29>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config29>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:43:9)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2_mult::weight_t*, config2_mult::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:347:5)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseLatency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>::dense(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:354:9)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[](unsigned long) const (.37)' into 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type*) (.36)' (firmware/nnet_utils/nnet_conv_stream.h:176:37)
# INFO: [HLS 214-131] Inlining function 'nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>) (.23)' into 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.22)' (firmware/nnet_utils/nnet_common.h:44:16)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.22)' into 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_pool<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, config6>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*) (.35)' (firmware/nnet_utils/nnet_pooling_stream.h:21:16)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type*) (.36)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&) (.32)' (firmware/nnet_utils/nnet_pooling_stream.h:142:5)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[](unsigned long) (.34)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&) (.32)' (firmware/nnet_utils/nnet_pooling_stream.h:157:13)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_pool<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, config6>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*) (.35)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&) (.32)' (firmware/nnet_utils/nnet_pooling_stream.h:157:30)
# INFO: [HLS 214-131] Inlining function 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&) (.32)' into 'void nnet::pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (firmware/nnet_utils/nnet_pooling_stream.h:187:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config30>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config30>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:33:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_data<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config30>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config30>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:38:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config30>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config30>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:43:9)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, config7_mult>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>*, config7_mult::weight_t*, config7_mult::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config7>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config7>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config7::weight_t*, config7::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:347:5)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseLatency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, config7_mult>::dense(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config7>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config7::weight_t*, config7::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:354:9)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long) const (.31)' into 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config11>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.30)' (firmware/nnet_utils/nnet_conv_stream.h:176:37)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.22)' into 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_pool<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, config11>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*) (.29)' (firmware/nnet_utils/nnet_pooling_stream.h:21:16)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config11>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*) (.30)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config11>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.27)' (firmware/nnet_utils/nnet_pooling_stream.h:142:5)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long) (.5)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config11>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.27)' (firmware/nnet_utils/nnet_pooling_stream.h:157:13)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_pool<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, config11>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*) (.29)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config11>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.27)' (firmware/nnet_utils/nnet_pooling_stream.h:157:30)
# INFO: [HLS 214-131] Inlining function 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config11>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.27)' into 'void nnet::pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config11>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_pooling_stream.h:187:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config31>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config31>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:33:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_data<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config31>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config31>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:38:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config31>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config31>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:43:9)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<23, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config12_mult>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<23, 15, (ap_q_mode)5, (ap_o_mode)3, 0>*, config12_mult::weight_t*, config12_mult::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config12>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<23, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config12>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<23, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, config12::weight_t*, config12::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:347:5)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseLatency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<23, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, config12_mult>::dense(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<23, 15, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<23, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config12>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u> const&, hls::stream<nnet::array<ap_fixed<23, 15, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, config12::weight_t*, config12::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:354:9)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[](unsigned long) const (.26)' into 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config16>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::value_type*) (.25)' (firmware/nnet_utils/nnet_conv_stream.h:176:37)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.22)' into 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_pool<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, config16>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*) (.21)' (firmware/nnet_utils/nnet_pooling_stream.h:21:16)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config16>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::value_type*) (.25)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config16>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&) (.19)' (firmware/nnet_utils/nnet_pooling_stream.h:142:5)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[](unsigned long) (.12)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config16>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&) (.19)' (firmware/nnet_utils/nnet_pooling_stream.h:157:13)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_pool<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, config16>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*) (.21)' into 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config16>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&) (.19)' (firmware/nnet_utils/nnet_pooling_stream.h:157:30)
# INFO: [HLS 214-131] Inlining function 'void nnet::compute_pool_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config16>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u> const&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&) (.19)' into 'void nnet::pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config16>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&)' (firmware/nnet_utils/nnet_pooling_stream.h:187:2)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_global_pool<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1, config17>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_global_pool<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config17>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u> const&, config17::accum_t*)' (firmware/nnet_utils/nnet_pooling_stream.h:222:26)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[](unsigned long) (.12)' into 'void nnet::data_prepare<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config18>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::value_type*) (.18)' (firmware/nnet_utils/nnet_dense_stream.h:47:17)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>*, config18::weight_t*, config18::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[](unsigned long) (.17)' into 'void nnet::res_write<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config18>(nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::value_type*, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&) (.15)' (firmware/nnet_utils/nnet_dense_stream.h:75:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::data_prepare<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config18>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::value_type*) (.18)' into 'void nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config18>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, config18::weight_t*, config18::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:93:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::res_write<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config18>(nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::value_type*, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&) (.15)' into 'void nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config18>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, config18::weight_t*, config18::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:100:5)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[](unsigned long) (.12)' into 'void nnet::data_prepare<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config22>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::value_type*) (.11)' (firmware/nnet_utils/nnet_dense_stream.h:47:17)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, config22>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>*, config22::weight_t*, config22::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[](unsigned long) (.10)' into 'void nnet::res_write<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config22>(nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.8)' (firmware/nnet_utils/nnet_dense_stream.h:75:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::data_prepare<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config22>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::value_type*) (.11)' into 'void nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config22>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config22::weight_t*, config22::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:93:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::res_write<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config22>(nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::value_type*, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&) (.8)' into 'void nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config22>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, 0>&, hls::stream<nnet::array<ap_fixed<22, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, 0>&, config22::weight_t*, config22::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:100:5)
# ...
# INFO: [HLS 200-1030] Apply Unified Pipeline Control on module 'global_pooling1d_cl_array_array_ap_fixed_32u_config17_Pipeline_ReadInput' pipeline 'ReadInput' pipeline type 'loop pipeline'
# INFO: [RTGEN 206-100] Finished creating RTL model for 'global_pooling1d_cl_array_array_ap_fixed_32u_config17_Pipeline_ReadInput'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.11 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.11 seconds; current allocated memory: 970.078 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_32u_config17_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_32u_config17_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.08 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.08 seconds; current allocated memory: 979.207 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_latency_wrapper_ap_fixed_ap_fixed_22_14_5_3_0_config18_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_latency_wrapper_ap_fixed_ap_fixed_22_14_5_3_0_config18_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.2 seconds. CPU system time: 0 seconds. Elapsed time: 0.2 seconds; current allocated memory: 990.102 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_ap_fixed_32u_array_ap_fixed_22_14_5_3_0_32u_config18_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_ap_fixed_32u_array_ap_fixed_22_14_5_3_0_32u_config18_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.37 seconds. CPU system time: 0.03 seconds. Elapsed time: 0.41 seconds; current allocated memory: 1.004 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'relu_array_ap_fixed_32u_array_ap_fixed_8_4_5_3_0_32u_relu_config21_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'relu_array_ap_fixed_32u_array_ap_fixed_8_4_5_3_0_32u_relu_config21_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.08 seconds. CPU system time: 0 seconds. Elapsed time: 0.08 seconds; current allocated memory: 1.016 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_latency_wrapper_ap_fixed_ap_fixed_22_14_5_3_0_config22_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_latency_wrapper_ap_fixed_ap_fixed_22_14_5_3_0_config22_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.14 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.14 seconds; current allocated memory: 1.019 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_ap_fixed_32u_array_ap_fixed_22_14_5_3_0_16u_config22_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_ap_fixed_32u_array_ap_fixed_22_14_5_3_0_16u_config22_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.22 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.24 seconds; current allocated memory: 1.037 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'relu_array_ap_fixed_16u_array_ap_fixed_8_4_5_3_0_16u_relu_config25_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'relu_array_ap_fixed_16u_array_ap_fixed_8_4_5_3_0_16u_relu_config25_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.07 seconds. CPU system time: 0 seconds. Elapsed time: 0.07 seconds; current allocated memory: 1.051 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_latency_wrapper_ap_fixed_ap_fixed_21_13_5_3_0_config26_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Generating core module 'mul_8s_5ns_13_1_0': 2 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8s_5s_13_1_0': 2 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_9s_5s_13_1_1': 1 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_latency_wrapper_ap_fixed_ap_fixed_21_13_5_3_0_config26_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.07 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.07 seconds; current allocated memory: 1.053 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_ap_fixed_16u_array_ap_fixed_21_13_5_3_0_1u_config26_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_ap_fixed_16u_array_ap_fixed_21_13_5_3_0_1u_config26_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.06 seconds. CPU system time: 0 seconds. Elapsed time: 0.06 seconds; current allocated memory: 1.055 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config28_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SYN 201-210] Renamed object name 'sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config28_s_sigmoid_table_ROM_AUTO_1R' to 'sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config28_s_sigmoid_table_RObkb' due to the length limit 80
# INFO: [RTGEN 206-100] Finished creating RTL model for 'sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config28_s'.
# INFO: [RTMG 210-279] Implementing memory 'myproject_sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config28_s_sigmoid_table_RObkb' using auto ROMs.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.06 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.06 seconds; current allocated memory: 1.058 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'myproject'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# WARNING: [RTGEN 206-101] Design contains AXI ports. Reset is fixed to synchronous and active low.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/input_1' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer28_out' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on function 'myproject' to 'ap_ctrl_hs'.
# INFO: [SYN 201-210] Renamed object name 'start_for_zeropad1d_cl_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_config30_U0' to 'start_for_zeropad1d_cl_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_config30cud' due to the length limit 80
# INFO: [SYN 201-210] Renamed object name 'start_for_conv_1d_cl_array_ap_fixed_8u_array_ap_fixed_22_14_5_3_0_16u_config7_U0' to 'start_for_conv_1d_cl_array_ap_fixed_8u_array_ap_fixed_22_14_5_3_0_16u_config7dEe' due to the length limit 80
# INFO: [RTGEN 206-100] Finished creating RTL model for 'myproject'.
# INFO: [RTMG 210-285] Implementing FIFO 'layer29_out_U(myproject_fifo_w8_d722_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_U(myproject_fifo_w152_d720_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_U(myproject_fifo_w64_d720_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_U(myproject_fifo_w64_d360_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer30_out_U(myproject_fifo_w64_d362_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer7_out_U(myproject_fifo_w352_d360_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer10_out_U(myproject_fifo_w128_d360_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer11_out_U(myproject_fifo_w128_d180_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer31_out_U(myproject_fifo_w128_d182_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer12_out_U(myproject_fifo_w736_d180_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer15_out_U(myproject_fifo_w256_d180_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_U(myproject_fifo_w256_d90_A)' using Vivado Default RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer17_out_U(myproject_fifo_w256_d1_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer18_out_U(myproject_fifo_w704_d1_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer21_out_U(myproject_fifo_w256_d1_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer22_out_U(myproject_fifo_w352_d1_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer25_out_U(myproject_fifo_w128_d1_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer26_out_U(myproject_fifo_w21_d1_S)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_19_11_5_3_0_8u_config2_U0_U(myproject_start_for_conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_19_11_5_3_0_8u_config2_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config5_U0_U(myproject_start_for_relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config5_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_pooling1d_cl_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_config6_U0_U(myproject_start_for_pooling1d_cl_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_config6_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_zeropad1d_cl_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_config30cud_U(myproject_start_for_zeropad1d_cl_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_config30cud)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_conv_1d_cl_array_ap_fixed_8u_array_ap_fixed_22_14_5_3_0_16u_config7dEe_U(myproject_start_for_conv_1d_cl_array_ap_fixed_8u_array_ap_fixed_22_14_5_3_0_16u_config7dEe)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_relu_array_ap_fixed_16u_array_ap_fixed_8_4_5_3_0_16u_relu_config10_U0_U(myproject_start_for_relu_array_ap_fixed_16u_array_ap_fixed_8_4_5_3_0_16u_relu_config10_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_16u_config11_U0_U(myproject_start_for_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_16u_config11_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_zeropad1d_cl_array_array_ap_fixed_8_4_5_3_0_16u_config31_U0_U(myproject_start_for_zeropad1d_cl_array_array_ap_fixed_8_4_5_3_0_16u_config31_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_conv_1d_cl_array_array_ap_fixed_23_15_5_3_0_32u_config12_U0_U(myproject_start_for_conv_1d_cl_array_array_ap_fixed_23_15_5_3_0_32u_config12_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_relu_array_ap_fixed_32u_array_ap_fixed_8_4_5_3_0_32u_relu_config15_U0_U(myproject_start_for_relu_array_ap_fixed_32u_array_ap_fixed_8_4_5_3_0_32u_relu_config15_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_32u_config16_U0_U(myproject_start_for_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_32u_config16_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_32u_config17_U0_U(myproject_start_for_global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_32u_config17_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_dense_array_ap_fixed_32u_array_ap_fixed_22_14_5_3_0_32u_config18_U0_U(myproject_start_for_dense_array_ap_fixed_32u_array_ap_fixed_22_14_5_3_0_32u_config18_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_relu_array_ap_fixed_32u_array_ap_fixed_8_4_5_3_0_32u_relu_config21_U0_U(myproject_start_for_relu_array_ap_fixed_32u_array_ap_fixed_8_4_5_3_0_32u_relu_config21_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_dense_array_ap_fixed_32u_array_ap_fixed_22_14_5_3_0_16u_config22_U0_U(myproject_start_for_dense_array_ap_fixed_32u_array_ap_fixed_22_14_5_3_0_16u_config22_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_relu_array_ap_fixed_16u_array_ap_fixed_8_4_5_3_0_16u_relu_config25_U0_U(myproject_start_for_relu_array_ap_fixed_16u_array_ap_fixed_8_4_5_3_0_16u_relu_config25_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_dense_array_ap_fixed_16u_array_ap_fixed_21_13_5_3_0_1u_config26_U0_U(myproject_start_for_dense_array_ap_fixed_16u_array_ap_fixed_21_13_5_3_0_1u_config26_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config28_U0_U(myproject_start_for_sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config28_U0)' using Shift Registers.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.21 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.22 seconds; current allocated memory: 1.059 GB.
# INFO: [HLS 200-111] Finished Generating all RTL models: CPU user time: 0.27 seconds. CPU system time: 0.02 seconds. Elapsed time: 0.3 seconds; current allocated memory: 1.063 GB.
# INFO: [HLS 200-111] Finished Updating report files: CPU user time: 1.01 seconds. CPU system time: 0.01 seconds. Elapsed time: 1.03 seconds; current allocated memory: 1.091 GB.
# INFO: [VHDL 208-304] Generating VHDL RTL for myproject.
# INFO: [VLOG 209-307] Generating Verilog RTL for myproject.
# INFO: [HLS 200-790] **** Loop Constraint Status: All loop constraints were NOT satisfied.
# INFO: [HLS 200-789] **** Estimated Fmax: 274.07 MHz
# INFO: [HLS 200-111] Finished Command csynth_design CPU user time: 44.02 seconds. CPU system time: 1.68 seconds. Elapsed time: 49.44 seconds; current allocated memory: 863.074 MB.
# ***** C/RTL SYNTHESIS COMPLETED IN 0h0m49s *****
# ***** EXPORT IP *****
# INFO: [HLS 200-1510] Running: export_design -format ip_catalog -version 1.0.0
# INFO: [IMPL 213-8] Exporting RTL as a Vivado IP.
#
# ****** Vivado v2023.2 (64-bit)
#   **** SW Build 4029153 on Fri Oct 13 20:13:54 MDT 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source run_ippack.tcl -notrace
# INFO: [IP_Flow 19-234] Refreshing IP repositories
# INFO: [IP_Flow 19-1704] No user IP repositories specified
# INFO: [IP_Flow 19-2313] Loaded Vivado IP repository '/tools/Xilinx/Vivado/2023.2/data/ip'.
# INFO: [Common 17-206] Exiting Vivado at Sat Jul 19 16:59:22 2025...

# %% [markdown]
# ## Check the reports

# %%
hls4ml.report.read_vivado_report('hls4ml/f_model_3_8b/')
