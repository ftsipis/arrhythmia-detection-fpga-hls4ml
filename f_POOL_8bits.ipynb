# %% [markdown]
# # Detecting arrythmia using Deep Leaning

# %% [markdown]
# ## Loading modules

# %%
import pandas as pd
import numpy as np
import wfdb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from pathlib import Path

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, TimeDistributed
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Download Dataset

# %%
from pathlib import Path
import zipfile

database_filename = "mit-bih-arrhythmia-database-1.0.0.zip"
expected_file = Path("mit-bih-arrhythmia-database-1.0.0")

if not expected_file.exists():
    with zipfile.ZipFile(database_filename, 'r') as zip_ref:
        zip_ref.extractall(".")
    print("Extraction complete.")
else:
    print("Files already extracted.")
# Out:
# Files already extracted.

# %% [markdown]
# ## Loading data

# %% [markdown]
# Loading list of records available, from dataset available [here](https://physionet.org/content/mitdb/1.0.0/)

# %%
records = np.loadtxt("mit-bih-arrhythmia-database-1.0.0/RECORDS", dtype=int)

# %% [markdown]
# Defining invalid beats as well as abnormal beats, according to [Physiobank](https://archive.physionet.org/physiobank/annotations.shtml)

# %%
invalid_beat = [
    "[", "!", "]", "x", "(", ")", "p", "t", 
    "u", "`", "'", "^", "|", "~", "+", "s", 
    "T", "*", "D", "=", '"', "@"
]

abnormal_beats = [
    "L", "R", "B", "A", "a", "J", "S", "V", 
    "r", "F", "e", "j", "n", "E", "/", "f", "Q", "?"
]

# %% [markdown]
# ## Processing dataset

# %% [markdown]
# This function classify a beat according to its symbol and the list provided above.

# %%
def classify_beat(symbol):
    if symbol in abnormal_beats:
        return 1
    elif symbol == "N" or symbol == ".":
        return 0

# %% [markdown]
# Given a signal, the beat location, and the window to be used as a sequence, this function gets the sequence. It will return an empty array in case of an invalid beat or empty sequence.

# %%
def get_sequence(signal, beat_loc, window_sec, fs):
    window_one_side = window_sec * fs
    beat_start = beat_loc - window_one_side
    beat_end = beat_loc + window_one_side
    if beat_end < signal.shape[0]:
        sequence = signal[beat_start:beat_end, 0]
        return sequence.reshape(1, -1, 1)
    else:
        return np.array([])

# %% [markdown]
# The code below will build a list of labels and sequences as well as map the sequences for each patient. The percentage calculated represents the ratio of abnormal beats in each patient data.

# %%
all_sequences = []
all_labels = []
window_sec = 3
subject_map = []
for subject in records:
    record = wfdb.rdrecord(f'mit-bih-arrhythmia-database-1.0.0/{subject}')
    annotation = wfdb.rdann(f'mit-bih-arrhythmia-database-1.0.0/{subject}', 'atr')
    atr_symbol = annotation.symbol
    atr_sample = annotation.sample
    fs = record.fs
    scaler = StandardScaler()
    signal = scaler.fit_transform(record.p_signal)
    subject_labels = []
    for i, i_sample in enumerate(atr_sample):
        label = classify_beat(atr_symbol[i])
        sequence = get_sequence(signal, i_sample, window_sec, fs)
        if label is not None and sequence.size > 0:
            all_sequences.append(sequence)
            subject_labels.append(label)

    normal_percentage = sum(subject_labels) / len(subject_labels)
    subject_map.append({
        "subject": subject,
        "percentage": normal_percentage,
        "num_seq": len(subject_labels),
        "start": len(all_labels),
        "end": len(all_labels)+len(subject_labels)
    })
    all_labels.extend(subject_labels)

# %%
print(subject_map[:5])
# Out:
# [{'subject': 100, 'percentage': 0.015017667844522967, 'num_seq': 2264, 'start': 0, 'end': 2264}, {'subject': 101, 'percentage': 0.002691065662002153, 'num_seq': 1858, 'start': 2264, 'end': 4122}, {'subject': 102, 'percentage': 0.9545663148233134, 'num_seq': 2179, 'start': 4122, 'end': 6301}, {'subject': 103, 'percentage': 0.0009624639076034649, 'num_seq': 2078, 'start': 6301, 'end': 8379}, {'subject': 104, 'percentage': 0.9266096352994146, 'num_seq': 2221, 'start': 8379, 'end': 10600}]

# %% [markdown]
# Creating bins to be used to stratify the train and validation split.

# %%
subject_map = pd.DataFrame(subject_map)

# %%
print(subject_map[:5])
# Out:
#    subject  percentage  num_seq  start    end
# 0      100    0.015018     2264      0   2264
# 1      101    0.002691     1858   2264   4122
# 2      102    0.954566     2179   4122   6301
# 3      103    0.000962     2078   6301   8379
# 4      104    0.926610     2221   8379  10600

# %% [markdown]
# The code presented will create class in each patient is segmented.

# %%
bins = [0, 0.2, 0.6, 1.0]
subject_map["bin"] = pd.cut(subject_map['percentage'], bins=bins, labels=False, include_lowest=True)

# %%
print(subject_map[:5])
# Out:
#    subject  percentage  num_seq  start    end  bin
# 0      100    0.015018     2264      0   2264    0
# 1      101    0.002691     1858   2264   4122    0
# 2      102    0.954566     2179   4122   6301    2
# 3      103    0.000962     2078   6301   8379    0
# 4      104    0.926610     2221   8379  10600    2

# %% [markdown]
# Now, the dataset is split into train and validation, stratifying by the bin defined above.

# %%
train, validation = train_test_split(subject_map, test_size=0.25, stratify=subject_map["bin"], random_state=42)

# %% [markdown]
# This function build a dataset based on the map for each split.

# %%
def build_dataset(df, all_sequences, all_labels):
    sequences = []
    labels = []
    for i, row in df.iterrows():
        start = int(row["start"])
        end = int(row["end"])
        sequences.extend(all_sequences[start:end])
        labels.extend(all_labels[start:end])
        
    return np.vstack(sequences), np.vstack(labels)

# %%
X_train, y_train = build_dataset(train, all_sequences, all_labels)
X_val, y_val = build_dataset(validation, all_sequences, all_labels)

# %%
X_train.shape, y_train.shape
# Out:
# ((82873, 2160, 1), (82873, 1))

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### CNN model

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.optimizers import Adam

sequence_size = X_train.shape[1]
n_features = 1

cnn_model = Sequential([
    Conv1D(
        filters=8,
        kernel_size=4,
        strides=1,
        input_shape=(sequence_size, n_features),
        padding="same",
        activation="relu"
    ),
    GlobalMaxPooling1D(),
    Dropout(0.5),
    Dense(
        1,
        activation="sigmoid",
        name="output",
    )
])

optimizer = Adam(learning_rate=0.001)
# Compiling the model
cnn_model.compile(
    optimizer=optimizer,
    loss="binary_crossentropy",
    metrics=["accuracy"]
)
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 2160, 8)           40
#
#  global_max_pooling1d (Glob  (None, 8)                 0
#  alMaxPooling1D)
#
#  dropout (Dropout)           (None, 8)                 0
#
#  output (Dense)              (None, 1)                 9
#
# =================================================================
# Total params: 49 (196.00 Byte)
# Trainable params: 49 (196.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import json

train = False
if train:
    hist_cnn = cnn_model.fit(
        X_train, 
        y_train, 
        batch_size=128,
        epochs=15,
        validation_data=(X_val, y_val)
    )
    cnn_model.save('NEW_model/cnn_model.keras')

    with open('NEW_model/hist_cnn.json', 'w') as f:
        json.dump(hist_cnn.history, f)

    with open('NEW_model/hist_cnn.json', 'r') as f:
        hist_cnn = json.load(f)
else:
    cnn_model = load_model('NEW_model/cnn_model.keras')

    with open('NEW_model/hist_cnn.json', 'r') as f:
        hist_cnn = json.load(f)

# %%
cnn_model.evaluate(X_val, y_val)
# Out:
# 821/821 [==============================] - 1s 524us/step - loss: 0.6080 - accuracy: 0.6799
# [0.6080105304718018, 0.6798811554908752]

# %%
# summarize history for accuracy
plt.plot(hist_cnn['accuracy'])
plt.plot(hist_cnn['val_accuracy'])
plt.title('CNN model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist_cnn['loss'])
plt.plot(hist_cnn['val_loss'])
plt.title('CNN model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Make an hls4ml config & model

# %%
import hls4ml
import plotting 

os.environ['PATH'] = os.environ['XILINX_VITIS'] + '/bin:' + os.environ['PATH']
config = hls4ml.utils.config_from_keras_model(cnn_model, granularity='name', backend='Vitis')
config['Model']['Precision'] = 'ap_fixed<8,4>'
print("-----------------------------------")
print("Configuration")
plotting.print_dict(config)
print("-----------------------------------")
hls_model = hls4ml.converters.convert_from_keras_model(cnn_model, hls_config=config, backend='Vitis', output_dir='hls4ml/f_8_bits', part='xcu250-figd2104-2L-e', io_type='io_stream')
# Out:
# Interpreting Sequential
# Topology:
# Layer name: conv1d_input, layer type: InputLayer, input shapes: [[None, 2160, 1]], output shape: [None, 2160, 1]
# Layer name: conv1d, layer type: Conv1D, input shapes: [[None, 2160, 1]], output shape: [None, 2160, 8]
# Layer name: global_max_pooling1d, layer type: GlobalMaxPooling1D, input shapes: [[None, 2160, 8]], output shape: [None, 8]
# Layer name: output, layer type: Dense, input shapes: [[None, 8]], output shape: [None, 1]
# -----------------------------------
# Configuration
# Model
#   Precision:         ap_fixed<8,4>
#   ReuseFactor:       1
#   Strategy:          Latency
#   BramFactor:        1000000000
#   TraceOutput:       False
# LayerName
#   conv1d_input
#     Trace:           False
#     Precision
#       result:        auto
#   conv1d
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#     ParallelizationFactor:1
#     ConvImplementation:LineBuffer
#   conv1d_relu
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
#   global_max_pooling1d
#     Trace:           False
#     Precision
#       result:        auto
#       accum:         auto
#     ReuseFactor:     1
#   output
#     Trace:           False
#     Precision
#       result:        auto
#       weight:        auto
#       bias:          auto
#       accum:         auto
#     ReuseFactor:     1
#   output_sigmoid
#     Trace:           False
#     Precision
#       result:        auto
#       table:         fixed<18,8,TRN,WRAP,0>
#     ReuseFactor:     1
#     TableSize:       1024
# -----------------------------------
# Interpreting Sequential
# Topology:
# Layer name: conv1d_input, layer type: InputLayer, input shapes: [[None, 2160, 1]], output shape: [None, 2160, 1]
# Layer name: conv1d, layer type: Conv1D, input shapes: [[None, 2160, 1]], output shape: [None, 2160, 8]
# Layer name: global_max_pooling1d, layer type: GlobalMaxPooling1D, input shapes: [[None, 2160, 8]], output shape: [None, 8]
# Layer name: output, layer type: Dense, input shapes: [[None, 8]], output shape: [None, 1]
# Creating HLS model

# %% [markdown]
# ## Visualise the model architecture

# %%
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=None)

# %% [markdown]
# ## Compile, predict

# %%
hls_model.compile()
X_val = np.ascontiguousarray(X_val)
y_hls = hls_model.predict(X_val)
# Out:
# Writing HLS project
# Done

# %% [markdown]
# ## HLS4ML Model Accuracy

# %%
from sklearn.metrics import accuracy_score

# Convert predictions to binary labels using a threshold of 0.5
y_hls_pred   = (y_hls > 0.5).astype("int32")

# Calculate accuracy using ground truth y_val
acc_hls   = accuracy_score(y_val, y_hls_pred)

print("HLS4ML Model Accuracy: {:.2f}%".format(acc_hls * 100))
# Out:
# HLS4ML Model Accuracy: 67.89%

# %% [markdown]
# ## Synthesize

# %%
hls_model.build(csim=False, synth=True, vsynth=True, export=True)
# Out:
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2023.2 (64-bit)
#   **** SW Build 4023990 on Oct 11 2023
#   **** IP Build 4028589 on Sat Oct 14 00:45:43 MDT 2023
#   **** SharedData Build 4025554 on Tue Oct 10 17:18:54 MDT 2023
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis_HLS/2023.2/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vitis_HLS/2023.2/bin/unwrapped/lnx64.o/vitis_hls'
# INFO: [HLS 200-10] For user 'fotis' on host 'fotis-Z390-UD' (Linux_x86_64 version 6.8.0-64-generic) on Sat Jul 19 16:21:46 EEST 2025
# INFO: [HLS 200-10] On os Ubuntu 24.04.2 LTS
# INFO: [HLS 200-10] In directory '/home/fotis/arrhythmia-detection/hls4ml/f_8_bits'
# INFO: [HLS 200-2053] The vitis_hls executable is being deprecated. Consider using vitis-run --mode hls --tcl
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-1510] Running: open_project myproject_prj
# INFO: [HLS 200-10] Creating and opening project '/home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj'.
# INFO: [HLS 200-1510] Running: set_top myproject
# INFO: [HLS 200-1510] Running: add_files firmware/myproject.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb myproject_test.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb firmware/weights
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-1510] Running: add_files -tb tb_data
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-1510] Running: open_solution solution1
# INFO: [HLS 200-10] Creating and opening solution '/home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1510] Running: config_array_partition -maximum_size 4096
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# ERROR: [HLS 200-642] The 'config_array_partition -maximum_size' command is not supported.
# INFO: [HLS 200-1510] Running: config_compile -name_max_length 80
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: set_part xcu250-figd2104-2L-e
# INFO: [HLS 200-1611] Setting target device to 'xcu250-figd2104-2L-e'
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: config_schedule -enable_dsp_full_reg=false
# INFO: [HLS 200-1510] Running: create_clock -period 5 -name default
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [HLS 200-1510] Running: set_clock_uncertainty 27% default
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 1.35ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [HLS 200-1510] Running: csynth_design
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 0.03 seconds. CPU system time: 0 seconds. Elapsed time: 0.03 seconds; current allocated memory: 256.426 MB.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:33:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:107:9)
# WARNING: [HLS 207-5536] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:189:9)
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:38:79)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:38:83)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:50:74)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body (firmware/myproject.cpp:50:78)
# Resolution: For help on HLS 214-113 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=214-113.html
# WARNING: [HLS 200-471] Dataflow form checks found 4 issue(s) in file firmware/myproject.cpp
# Resolution: For help on HLS 200-471 see docs.xilinx.com/access/sources/dita/topic?Doc_Version=2023.2%20English&url=ug1448-hls-guidance&resourceid=200-471.html
# WARNING: [HLS 207-5292] unused parameter 'keep' (firmware/nnet_utils/nnet_helpers.h:285:99)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:14:36)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:15:36)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:16:44)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:24:24)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:25:24)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:26:32)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:33:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:33:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:34:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:35:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:42:30)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:42:58)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:43:51)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:44:49)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:51:29)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:51:80)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:52:50)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:53:48)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:16:39)
# WARNING: [HLS 207-5292] unused parameter 'res' (firmware/nnet_utils/nnet_code_gen.h:17:38)
# WARNING: [HLS 207-5292] unused parameter 'weights' (firmware/nnet_utils/nnet_code_gen.h:18:60)
# WARNING: [HLS 207-5292] unused parameter 'biases' (firmware/nnet_utils/nnet_code_gen.h:19:58)
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 3.81 seconds. CPU system time: 0.38 seconds. Elapsed time: 4.19 seconds; current allocated memory: 264.609 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# INFO: [HLS 200-1995] There were 4,243 instructions in the design after the 'Compile/Link' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 4,014 instructions in the design after the 'Unroll/Inline (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,661 instructions in the design after the 'Unroll/Inline (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,527 instructions in the design after the 'Unroll/Inline (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,240 instructions in the design after the 'Unroll/Inline (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 747 instructions in the design after the 'Array/Struct (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 747 instructions in the design after the 'Array/Struct (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 759 instructions in the design after the 'Array/Struct (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,093 instructions in the design after the 'Array/Struct (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,088 instructions in the design after the 'Array/Struct (step 5)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,068 instructions in the design after the 'Performance (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,057 instructions in the design after the 'Performance (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,055 instructions in the design after the 'Performance (step 3)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,055 instructions in the design after the 'Performance (step 4)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 976 instructions in the design after the 'HW Transforms (step 1)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 200-1995] There were 1,018 instructions in the design after the 'HW Transforms (step 2)' phase of compilation. See the Design Size Report for more details: /home/fotis/arrhythmia-detection/hls4ml/f_8_bits/myproject_prj/solution1/syn/report/csynth_design_size.rpt
# INFO: [HLS 214-415] Performing recursive inline in function 'nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config5>' (firmware/nnet_utils/nnet_dense_stream.h:85:9)
# WARNING: [HLS 214-273] In function 'void nnet::dense_latency_wrapper<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)', Pragma conflict happens on 'INLINE' and 'PIPELINE' pragmas: same function (firmware/nnet_utils/nnet_dense_stream.h:15:0)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:33:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_data<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:38:9)
# INFO: [HLS 214-131] Inlining function 'void nnet::fill_zero<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:43:9)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2_mult::weight_t*, config2_mult::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'void nnet::kernel_shift_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:347:5)
# INFO: [HLS 214-131] Inlining function 'nnet::DenseLatency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>::dense(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:354:9)
# INFO: [HLS 214-131] Inlining function 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce_global_pool<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1, config4>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'void nnet::compute_global_pool<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, config4::accum_t*)' (firmware/nnet_utils/nnet_pooling_stream.h:222:26)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[](unsigned long) (.5)' into 'void nnet::data_prepare<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type*) (.4)' (firmware/nnet_utils/nnet_dense_stream.h:47:17)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long) (.3)' into 'void nnet::res_write<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config5>(nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*, hls::stream<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&) (.1)' (firmware/nnet_utils/nnet_dense_stream.h:75:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::data_prepare<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::value_type*) (.4)' into 'void nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config5>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, config5::weight_t*, config5::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:93:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::res_write<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config5>(nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::value_type*, hls::stream<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&) (.1)' into 'void nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config5>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, config5::weight_t*, config5::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:100:5)
# INFO: [HLS 214-291] Loop 'SigmoidPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:88:9)
# INFO: [HLS 214-291] Loop 'Result' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:64:5)
# INFO: [HLS 214-291] Loop 'Accum1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:54:5)
# INFO: [HLS 214-291] Loop 'Accum2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:56:9)
# INFO: [HLS 214-291] Loop 'ResetAccum' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:48:5)
# INFO: [HLS 214-291] Loop 'Product1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:37:5)
# INFO: [HLS 214-291] Loop 'Product2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:40:9)
# INFO: [HLS 214-291] Loop 'MaxPoolPack' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_pooling_stream.h:319:13)
# INFO: [HLS 214-291] Loop 'ReLUPackLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation_stream.h:49:9)
# INFO: [HLS 214-291] Loop 'CastLoop' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:359:9)
# INFO: [HLS 214-291] Loop 'KernelPushChannel' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:174:5)
# INFO: [HLS 214-291] Loop 'KernelShiftWidth' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:161:5)
# INFO: [HLS 214-291] Loop 'KernelShiftChannel' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_conv_stream.h:164:9)
# INFO: [HLS 214-186] Unrolling loop 'SigmoidPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:88:9) in function 'nnet::sigmoid<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, sigmoid_config6>' completely with a factor of 1 (firmware/nnet_utils/nnet_activation_stream.h:65:0)
# INFO: [HLS 214-186] Unrolling loop 'ResPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:73:9) in function 'nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config5>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'DataPackSingle' (firmware/nnet_utils/nnet_dense_stream.h:45:9) in function 'nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config5>' completely with a factor of 8 (firmware/nnet_utils/nnet_dense_stream.h:84:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 8 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 8 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 1 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'MaxPoolPack' (firmware/nnet_utils/nnet_pooling_stream.h:319:13) in function 'nnet::global_pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' completely with a factor of 8 (firmware/nnet_utils/nnet_pooling_stream.h:287:0)
# INFO: [HLS 214-186] Unrolling loop 'PoolInitLoop' (firmware/nnet_utils/nnet_pooling_stream.h:300:5) in function 'nnet::global_pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' completely with a factor of 8 (firmware/nnet_utils/nnet_pooling_stream.h:287:0)
# INFO: [HLS 214-186] Unrolling loop 'PoolFilt' (firmware/nnet_utils/nnet_pooling_stream.h:211:5) in function 'nnet::compute_global_pool<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' completely with a factor of 8 (firmware/nnet_utils/nnet_pooling_stream.h:209:0)
# INFO: [HLS 214-186] Unrolling loop 'PixelLoop' (firmware/nnet_utils/nnet_pooling_stream.h:218:9) in function 'nnet::compute_global_pool<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' completely with a factor of 1 (firmware/nnet_utils/nnet_pooling_stream.h:209:0)
# INFO: [HLS 214-186] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49:9) in function 'nnet::relu<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>' completely with a factor of 8 (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-186] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:359:9) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' completely with a factor of 8 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelPushChannel' (firmware/nnet_utils/nnet_conv_stream.h:174:5) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' completely with a factor of 1 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' completely with a factor of 3 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# WARNING: [HLS 214-189] Pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:161:5) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' has been removed because the loop is unrolled completely (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:164:9) in function 'nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' completely with a factor of 1 (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 8 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 4 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 8 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 8 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 4 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' completely with a factor of 8 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_22_1' (firmware/nnet_utils/nnet_padding_stream.h:22:22) in function 'nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>' completely with a factor of 1 (firmware/nnet_utils/nnet_padding_stream.h:30:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long)' into 'void nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_padding_stream.h:30:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_uint<1> >::value), ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(config2_mult::accum_t)' into 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2_mult::weight_t*, config2_mult::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long) const' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[](unsigned long)' into 'void nnet::compute_output_buffer_1d<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&, hls::stream<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_conv_stream.h:327:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[](unsigned long)' into 'void nnet::relu<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>(hls::stream<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[](unsigned long)' into 'void nnet::relu<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>(hls::stream<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:39:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[](unsigned long) const' into 'void nnet::compute_global_pool<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, config4::accum_t*)' (firmware/nnet_utils/nnet_pooling_stream.h:209:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'void nnet::compute_global_pool<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>(nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u> const&, config4::accum_t*)' (firmware/nnet_utils/nnet_pooling_stream.h:209:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[](unsigned long)' into 'void nnet::global_pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>(hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, 0>&)' (firmware/nnet_utils/nnet_pooling_stream.h:287:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_uint<1> >::value), ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(config5::accum_t)' into 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long)' into 'void nnet::sigmoid<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, sigmoid_config6>(hls::stream<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:65:0)
# INFO: [HLS 214-178] Inlining function 'nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[](unsigned long)' into 'void nnet::sigmoid<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, sigmoid_config6>(hls::stream<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&, hls::stream<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, 0>&)' (firmware/nnet_utils/nnet_activation_stream.h:65:0)
# INFO: [HLS 214-248] Applying array_partition to 'b2': Complete partitioning on dimension 1. (firmware/weights/b2.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to 'b5': Complete partitioning on dimension 1. (firmware/weights/b5.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to '_ZZN4nnet24compute_output_buffer_1dINS_5arrayI8ap_fixedILi8ELi4EL9ap_q_mode5EL9ap_o_mode3ELi0EELj1EEENS1_IS2_ILi19ELi11ELS3_5ELS4_3ELi0EELj8EEE7config2EEvRKT_RN3hls6streamIT0_Li0EEEPNT1_8weight_tEPNSI_6bias_tEE11kernel_data': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_conv_stream.h:337:0)
# INFO: [HLS 214-248] Applying array_partition to 'res_out': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_conv_stream.h:340:29)
# INFO: [HLS 214-248] Applying array_partition to 'data_window': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_pooling_stream.h:291:32)
# INFO: [HLS 214-248] Applying array_partition to 'data': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_stream.h:87:30)
# INFO: [HLS 214-248] Applying array_partition to 'res': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_stream.h:90:29)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer5_out' with compact=bit mode in 20-bits (firmware/myproject.cpp:48:34)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer4_out' with compact=bit mode in 64-bits (firmware/myproject.cpp:44:27)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer3_out' with compact=bit mode in 64-bits (firmware/myproject.cpp:40:27)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer2_out' with compact=bit mode in 152-bits (firmware/myproject.cpp:36:34)
# INFO: [HLS 214-241] Aggregating fifo (hls::stream) variable 'layer7_out' with compact=bit mode in 8-bits (firmware/myproject.cpp:32:24)
# INFO: [HLS 214-364] Automatically inlining function 'void nnet::dense_latency<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' to improve effectiveness of pipeline pragma in function 'void nnet::dense_latency_wrapper<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' (firmware/nnet_utils/nnet_dense_stream.h:17:2)
# INFO: [HLS 214-376] automatically set the pipeline for Loop< ReadInput> at firmware/nnet_utils/nnet_pooling_stream.h:306:5
# INFO: [HLS 214-376] automatically set the pipeline for Loop< CopyMain> at firmware/nnet_utils/nnet_padding_stream.h:37:5
# INFO: [HLS 214-376] automatically set the pipeline for Loop< PadRight> at firmware/nnet_utils/nnet_padding_stream.h:42:5
# INFO: [HLS 200-111] Finished Compiling Optimization and Transform: CPU user time: 1.71 seconds. CPU system time: 0.4 seconds. Elapsed time: 6.49 seconds; current allocated memory: 266.422 MB.
# INFO: [HLS 200-111] Finished Checking Pragmas: CPU user time: 0 seconds. CPU system time: 0 seconds. Elapsed time: 0 seconds; current allocated memory: 266.422 MB.
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-111] Finished Standard Transforms: CPU user time: 0.02 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.02 seconds; current allocated memory: 268.574 MB.
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [XFORM 203-602] Inlining function 'nnet::compute_global_pool<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' into 'nnet::global_pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' (firmware/nnet_utils/nnet_pooling_stream.h:308) automatically.
# INFO: [HLS 200-111] Finished Checking Synthesizability: CPU user time: 0.03 seconds. CPU system time: 0 seconds. Elapsed time: 0.04 seconds; current allocated memory: 271.172 MB.
# INFO: [XFORM 203-102] Partitioning array 'ref.tmp6' automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::compute_global_pool<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' into 'nnet::global_pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' (firmware/nnet_utils/nnet_pooling_stream.h:308) automatically.
# INFO: [XFORM 203-712] Applying dataflow to function 'myproject' (firmware/myproject.cpp:8), detected/extracted 6 process function(s):
# 	 'nnet::zeropad1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config7>'
# 	 'nnet::conv_1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>'
# 	 'nnet::relu<nnet::array<ap_fixed<19, 11, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>'
# 	 'nnet::global_pooling1d_cl<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>'
# 	 'nnet::dense<nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config5>'
# 	 'nnet::sigmoid<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, sigmoid_config6>'.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock to (firmware/nnet_utils/nnet_activation_stream.h:101:1) in function 'nnet::sigmoid<nnet::array<ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, sigmoid_config6>'... converting 3 basic blocks.
# INFO: [XFORM 203-11] Balancing expressions in function 'nnet::dense_latency_wrapper<ap_fixed<8, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<20, 12, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' (firmware/nnet_utils/nnet_dense_stream.h:18:1)...3 expression(s) balanced.
# INFO: [HLS 200-111] Finished Loop, function and other optimizations: CPU user time: 0.09 seconds. CPU system time: 0 seconds. Elapsed time: 0.09 seconds; current allocated memory: 296.812 MB.
# INFO: [HLS 200-111] Finished Architecture Synthesis: CPU user time: 0.06 seconds. CPU system time: 0.02 seconds. Elapsed time: 0.08 seconds; current allocated memory: 405.406 MB.
# INFO: [HLS 200-10] Starting hardware synthesis ...
# INFO: [HLS 200-10] Synthesizing 'myproject' ...
# WARNING: [SYN 201-103] Legalizing function name 'zeropad1d_cl<array,array<ap_fixed<8,4,5,3,0>,1u>,config7>_Pipeline_CopyMain' to 'zeropad1d_cl_array_array_ap_fixed_8_4_5_3_0_1u_config7_Pipeline_CopyMain'.
# WARNING: [SYN 201-103] Legalizing function name 'zeropad1d_cl<array,array<ap_fixed<8,4,5,3,0>,1u>,config7>_Pipeline_PadRight' to 'zeropad1d_cl_array_array_ap_fixed_8_4_5_3_0_1u_config7_Pipeline_PadRight'.
# WARNING: [SYN 201-103] Legalizing function name 'zeropad1d_cl<array<ap_fixed,1u>,array<ap_fixed<8,4,5,3,0>,1u>,config7>' to 'zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_8_4_5_3_0_1u_config7_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense_latency<ap_fixed<8, 4, 5, 3, 0>, ap_fixed<19, 11, 5, 3, 0>, config2_mult>' to 'dense_latency_ap_fixed_8_4_5_3_0_ap_fixed_19_11_5_3_0_config2_mult_s'.
# WARNING: [SYN 201-103] Legalizing function name 'compute_output_buffer_1d<array,array<ap_fixed<19,11,5,3,0>,8u>,config2>' to 'compute_output_buffer_1d_array_array_ap_fixed_19_11_5_3_0_8u_config2_s'.
# WARNING: [SYN 201-103] Legalizing function name 'conv_1d_cl<array<ap_fixed,1u>,array<ap_fixed<19,11,5,3,0>,8u>,config2>' to 'conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_19_11_5_3_0_8u_config2_s'.
# WARNING: [SYN 201-103] Legalizing function name 'relu<array<ap_fixed,8u>,array<ap_fixed<8,4,5,3,0>,8u>,relu_config3>' to 'relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config3_s'.
# WARNING: [SYN 201-103] Legalizing function name 'global_pooling1d_cl<array,array<ap_fixed,8u>,config4>_Pipeline_ReadInput' to 'global_pooling1d_cl_array_array_ap_fixed_8u_config4_Pipeline_ReadInput'.
# WARNING: [SYN 201-103] Legalizing function name 'global_pooling1d_cl<array,array<ap_fixed<8,4,5,3,0>,8u>,config4>' to 'global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_8u_config4_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense_latency_wrapper<ap_fixed,ap_fixed<20,12,5,3,0>,config5>' to 'dense_latency_wrapper_ap_fixed_ap_fixed_20_12_5_3_0_config5_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense<array<ap_fixed,8u>,array<ap_fixed<20,12,5,3,0>,1u>,config5>' to 'dense_array_ap_fixed_8u_array_ap_fixed_20_12_5_3_0_1u_config5_s'.
# WARNING: [SYN 201-103] Legalizing function name 'sigmoid<array,array<ap_fixed<8,4,5,3,0>,1u>,sigmoid_config6>' to 'sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_s'.
# WARNING: [SYN 201-223] Checking resource limit in 'dense_latency<ap_fixed<8, 4, 5, 3, 0>, ap_fixed<19, 11, 5, 3, 0>, config2_mult>': cannot find any operation of 'mul'.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'zeropad1d_cl_array_array_ap_fixed_8_4_5_3_0_1u_config7_Pipeline_CopyMain'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining loop 'CopyMain'.
# INFO: [HLS 200-1470] Pipelining result : Target II = NA, Final II = 1, Depth = 2, loop 'CopyMain'
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111] Finished Scheduling: CPU user time: 0.03 seconds. CPU system time: 0.01 seconds. Elapsed time: 0.04 seconds; current allocated memory: 407.066 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# ...
# |23    |    U_myproject_fifo_w8_d2163_A_ram                                                    |myproject_fifo_w8_d2163_A_ram                                                              |    75|
# |24    |  relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config3_U0                   |myproject_relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config3_s                |   124|
# |25    |    flow_control_loop_pipe_U                                                           |myproject_flow_control_loop_pipe                                                           |    28|
# |26    |  sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_U0                         |myproject_sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_s                      |    98|
# |27    |    regslice_both_layer6_out_U                                                         |myproject_regslice_both_1                                                                  |    27|
# |28    |    sigmoid_table_U                                                                    |myproject_sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_s_sigmoid_table_ROMbkb |    16|
# |29    |  start_for_conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_19_11_5_3_0_8u_config2_U0_U    |myproject_start_for_conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_19_11_5_3_0_8u_config2_U0  |    11|
# |30    |  start_for_dense_array_ap_fixed_8u_array_ap_fixed_20_12_5_3_0_1u_config5_U0_U         |myproject_start_for_dense_array_ap_fixed_8u_array_ap_fixed_20_12_5_3_0_1u_config5_U0       |    11|
# |31    |  start_for_global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_8u_config4_U0_U         |myproject_start_for_global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_8u_config4_U0       |    12|
# |32    |  start_for_relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config3_U0_U       |myproject_start_for_relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config3_U0     |     8|
# |33    |  start_for_sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_U0_U             |myproject_start_for_sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_U0           |     8|
# |34    |  zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_8_4_5_3_0_1u_config7_U0                |myproject_zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_8_4_5_3_0_1u_config7_s             |   127|
# |35    |    grp_zeropad1d_cl_array_array_ap_fixed_8_4_5_3_0_1u_config7_Pipeline_CopyMain_fu_38 |myproject_zeropad1d_cl_array_array_ap_fixed_8_4_5_3_0_1u_config7_Pipeline_CopyMain         |    66|
# |36    |      flow_control_loop_pipe_sequential_init_U                                         |myproject_flow_control_loop_pipe_sequential_init_0                                         |    35|
# |37    |    grp_zeropad1d_cl_array_array_ap_fixed_8_4_5_3_0_1u_config7_Pipeline_PadRight_fu_46 |myproject_zeropad1d_cl_array_array_ap_fixed_8_4_5_3_0_1u_config7_Pipeline_PadRight         |    18|
# |38    |      flow_control_loop_pipe_sequential_init_U                                         |myproject_flow_control_loop_pipe_sequential_init                                           |    14|
# |39    |    regslice_both_conv1d_input_U                                                       |myproject_regslice_both                                                                    |    32|
# +------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------+------+
# ---------------------------------------------------------------------------------
# Finished Writing Synthesis Report : Time (s): cpu = 00:00:10 ; elapsed = 00:00:11 . Memory (MB): peak = 2879.949 ; gain = 1532.578 ; free physical = 10299 ; free virtual = 23120
# ---------------------------------------------------------------------------------
# Synthesis finished with 0 errors, 0 critical warnings and 479 warnings.
# Synthesis Optimization Runtime : Time (s): cpu = 00:00:10 ; elapsed = 00:00:11 . Memory (MB): peak = 2879.949 ; gain = 1532.578 ; free physical = 10299 ; free virtual = 23120
# Synthesis Optimization Complete : Time (s): cpu = 00:00:10 ; elapsed = 00:00:11 . Memory (MB): peak = 2879.957 ; gain = 1532.578 ; free physical = 10299 ; free virtual = 23120
# INFO: [Project 1-571] Translating synthesized netlist
# Netlist sorting complete. Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00.02 . Memory (MB): peak = 2893.887 ; gain = 0.000 ; free physical = 10559 ; free virtual = 23377
# INFO: [Netlist 29-17] Analyzing 161 Unisim elements for replacement
# INFO: [Netlist 29-28] Unisim Transformation completed in 0 CPU seconds
# INFO: [Project 1-570] Preparing netlist for logic optimization
# INFO: [Opt 31-138] Pushed 0 inverter(s) to 0 load pin(s).
# Netlist sorting complete. Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3037.531 ; gain = 0.000 ; free physical = 10475 ; free virtual = 23292
# INFO: [Project 1-111] Unisim Transformation Summary:
#   A total of 14 instances were transformed.
#   BUFG => BUFGCE: 1 instance
#   IBUF => IBUF (IBUFCTRL, INBUF): 13 instances
#
# Synth Design complete | Checksum: 54b4154c
# INFO: [Common 17-83] Releasing license: Synthesis
# 121 Infos, 119 Warnings, 0 Critical Warnings and 0 Errors encountered.
# synth_design completed successfully
# synth_design: Time (s): cpu = 00:00:14 ; elapsed = 00:00:12 . Memory (MB): peak = 3037.566 ; gain = 1699.133 ; free physical = 10465 ; free virtual = 23282
# INFO: [Common 17-2834] synth_design peak Physical Memory [PSS] (MB): overall = 2556.351; main = 2316.918; forked = 384.170
# INFO: [Common 17-2834] synth_design peak Virtual Memory [VSS] (MB): overall = 3873.559; main = 3037.535; forked = 993.605
# # opt_design -retarget -propconst -sweep -bram_power_opt -shift_register_opt
# Command: opt_design -retarget -propconst -sweep -bram_power_opt -shift_register_opt
# Attempting to get a license for feature 'Implementation' and/or device 'xcu250'
# INFO: [Common 17-349] Got license for feature 'Implementation' and/or device 'xcu250'
# Running DRC as a precondition to command opt_design
#
# Starting DRC Task
# INFO: [DRC 23-27] Running DRC with 8 threads
# INFO: [Project 1-461] DRC finished with 0 Errors
# INFO: [Project 1-462] Please refer to the DRC report (report_drc) for more information.
#
# Time (s): cpu = 00:00:01 ; elapsed = 00:00:00.73 . Memory (MB): peak = 3101.562 ; gain = 63.996 ; free physical = 10496 ; free virtual = 23314
#
# Starting Cache Timing Information Task
# INFO: [Timing 38-35] Done setting XDC timing constraints.
# Ending Cache Timing Information Task | Checksum: 1533f0565
#
# Time (s): cpu = 00:00:00.64 ; elapsed = 00:00:00.57 . Memory (MB): peak = 3150.047 ; gain = 48.484 ; free physical = 10491 ; free virtual = 23309
#
# Starting Logic Optimization Task
#
# Phase 1 Initialization
#
# Phase 1.1 Core Generation And Design Setup
# Phase 1.1 Core Generation And Design Setup | Checksum: 1533f0565
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
#
# Phase 1.2 Setup Constraints And Sort Netlist
# Phase 1.2 Setup Constraints And Sort Netlist | Checksum: 1533f0565
#
# Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# Phase 1 Initialization | Checksum: 1533f0565
#
# Time (s): cpu = 00:00:00.01 ; elapsed = 00:00:00 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
#
# Phase 2 Timer Update And Timing Data Collection
#
# Phase 2.1 Timer Update
# Phase 2.1 Timer Update | Checksum: 1533f0565
#
# Time (s): cpu = 00:00:00.04 ; elapsed = 00:00:00.01 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
#
# Phase 2.2 Timing Data Collection
# Phase 2.2 Timing Data Collection | Checksum: 1533f0565
#
# Time (s): cpu = 00:00:00.04 ; elapsed = 00:00:00.02 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# Phase 2 Timer Update And Timing Data Collection | Checksum: 1533f0565
#
# Time (s): cpu = 00:00:00.04 ; elapsed = 00:00:00.02 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
#
# Phase 3 Retarget
# INFO: [Opt 31-1566] Pulled 1 inverters resulting in an inversion of 3 pins
# INFO: [Opt 31-138] Pushed 1 inverter(s) to 233 load pin(s).
# INFO: [Opt 31-49] Retargeted 0 cell(s).
# Phase 3 Retarget | Checksum: 646998da
#
# Time (s): cpu = 00:00:00.12 ; elapsed = 00:00:00.05 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# Retarget | Checksum: 646998da
# INFO: [Opt 31-389] Phase Retarget created 0 cells and removed 2 cells
#
# Phase 4 Constant propagation
# INFO: [Opt 31-138] Pushed 0 inverter(s) to 0 load pin(s).
# Phase 4 Constant propagation | Checksum: f73c7f42
#
# Time (s): cpu = 00:00:00.13 ; elapsed = 00:00:00.06 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# Constant propagation | Checksum: f73c7f42
# INFO: [Opt 31-389] Phase Constant propagation created 0 cells and removed 0 cells
#
# Phase 5 Sweep
# Phase 5 Sweep | Checksum: 7a12edb4
#
# Time (s): cpu = 00:00:00.15 ; elapsed = 00:00:00.08 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# Sweep | Checksum: 7a12edb4
# INFO: [Opt 31-389] Phase Sweep created 0 cells and removed 0 cells
#
# Phase 6 Shift Register Optimization
# INFO: [Opt 31-1064] SRL Remap converted 0 SRLs to 0 registers and converted 0 registers of register chains to 0 SRLs
# Phase 6 Shift Register Optimization | Checksum: 7a12edb4
#
# Time (s): cpu = 00:00:00.15 ; elapsed = 00:00:00.08 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# Shift Register Optimization | Checksum: 7a12edb4
# INFO: [Opt 31-389] Phase Shift Register Optimization created 0 cells and removed 0 cells
#
# Phase 7 Post Processing Netlist
# Phase 7 Post Processing Netlist | Checksum: 7a12edb4
#
# Time (s): cpu = 00:00:00.15 ; elapsed = 00:00:00.08 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# Post Processing Netlist | Checksum: 7a12edb4
# INFO: [Opt 31-389] Phase Post Processing Netlist created 0 cells and removed 0 cells
#
# Phase 8 Finalization
#
# Phase 8.1 Finalizing Design Cores and Updating Shapes
# Phase 8.1 Finalizing Design Cores and Updating Shapes | Checksum: 1821f8e00
#
# Time (s): cpu = 00:00:00.25 ; elapsed = 00:00:00.13 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
#
# Phase 8.2 Verifying Netlist Connectivity
# Phase 8.2 Verifying Netlist Connectivity | Checksum: 1821f8e00
#
# Time (s): cpu = 00:00:00.25 ; elapsed = 00:00:00.13 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# Phase 8 Finalization | Checksum: 1821f8e00
#
# Time (s): cpu = 00:00:00.25 ; elapsed = 00:00:00.13 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# Opt_design Change Summary
# =========================
#
#
# -------------------------------------------------------------------------------------------------------------------------
# |  Phase                        |  #Cells created  |  #Cells Removed  |  #Constrained objects preventing optimizations  |
# -------------------------------------------------------------------------------------------------------------------------
# |  Retarget                     |               0  |               2  |                                              0  |
# |  Constant propagation         |               0  |               0  |                                              0  |
# |  Sweep                        |               0  |               0  |                                              0  |
# |  Shift Register Optimization  |               0  |               0  |                                              0  |
# |  Post Processing Netlist      |               0  |               0  |                                              0  |
# -------------------------------------------------------------------------------------------------------------------------
#
#
# Ending Logic Optimization Task | Checksum: 1821f8e00
#
# Time (s): cpu = 00:00:00.25 ; elapsed = 00:00:00.13 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
# INFO: [Constraints 18-11670] Building netlist checker database with flags, 0x8
# Done building netlist checker database: Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3386.047 ; gain = 0.000 ; free physical = 10238 ; free virtual = 23055
#
# Starting Power Optimization Task
# INFO: [Pwropt 34-132] Skipping clock gating for clocks with a period < 2.00 ns.
# INFO: [Pwropt 34-9] Applying IDT optimizations ...
# INFO: [Pwropt 34-10] Applying ODC optimizations ...
# INFO: [Timing 38-35] Done setting XDC timing constraints.
# WARNING: [Power 33-232] No user defined clocks were found in the design! Power estimation will be inaccurate until this is corrected.
# Resolution: Please specify clocks using create_clock/create_generated_clock for sequential elements. For pure combinatorial circuits, please specify a virtual clock, otherwise the vectorless estimation might be inaccurate
# Running Vector-less Activity Propagation...
#
# Finished Running Vector-less Activity Propagation
#
#
# Starting PowerOpt Patch Enables Task
# INFO: [Pwropt 34-162] WRITE_MODE attribute of 0 BRAM(s) out of a total of 2 has been updated to save power. Run report_power_opt to get a complete listing of the BRAMs updated.
# INFO: [Pwropt 34-201] Structural ODC has moved 1 WE to EN ports
# Number of BRAM Ports augmented: 0 newly gated: 1 Total Ports: 4
# Ending PowerOpt Patch Enables Task | Checksum: e34c0afa
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00.01 . Memory (MB): peak = 3669.598 ; gain = 0.000 ; free physical = 10125 ; free virtual = 22943
# Ending Power Optimization Task | Checksum: e34c0afa
#
# Time (s): cpu = 00:00:06 ; elapsed = 00:00:05 . Memory (MB): peak = 3669.598 ; gain = 283.551 ; free physical = 10125 ; free virtual = 22943
#
# Starting Final Cleanup Task
# Ending Final Cleanup Task | Checksum: e34c0afa
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3669.598 ; gain = 0.000 ; free physical = 10125 ; free virtual = 22943
#
# Starting Netlist Obfuscation Task
# Netlist sorting complete. Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3669.598 ; gain = 0.000 ; free physical = 10125 ; free virtual = 22943
# Ending Netlist Obfuscation Task | Checksum: 142cb6941
#
# Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 3669.598 ; gain = 0.000 ; free physical = 10125 ; free virtual = 22943
# INFO: [Common 17-83] Releasing license: Implementation
# 23 Infos, 1 Warnings, 0 Critical Warnings and 0 Errors encountered.
# opt_design completed successfully
# opt_design: Time (s): cpu = 00:00:09 ; elapsed = 00:00:08 . Memory (MB): peak = 3669.598 ; gain = 632.031 ; free physical = 10125 ; free virtual = 22943
# # report_utilization -file vivado_synth.rpt
# INFO: [Common 17-206] Exiting Vivado at Sat Jul 19 16:22:40 2025...
# ***** VIVADO SYNTHESIS COMPLETED IN 0h0m35s *****
# INFO: [HLS 200-112] Total CPU user time: 42.63 seconds. Total CPU system time: 2.69 seconds. Total elapsed time: 64.47 seconds; peak allocated memory: 444.078 MB.
# INFO: [Common 17-206] Exiting vitis_hls at Sat Jul 19 16:22:51 2025...
# Cosim report not found.
# Timing report not found.
# {'CSynthesisReport': {'TargetClockPeriod': '5.00',
#   'EstimatedClockPeriod': '3.302',
#   'BestLatency': '4335',
#   'WorstLatency': '4335',
#   'IntervalMin': '4330',
#   'IntervalMax': '4330',
#   'BRAM_18K': '12',
#   'DSP': '0',
#   'FF': '1573',
#   'LUT': '3602',
#   'URAM': '0',
#   'AvailableBRAM_18K': '5376',
#   'AvailableDSP': '12288',
#   'AvailableFF': '3456000',
#   'AvailableLUT': '1728000',
#   'AvailableURAM': '1280'},
#  'VivadoSynthReport': {'LUT': '1133',
#   'FF': '851',
#   'BRAM_18K': '1.5',
#   'URAM': '4',
#   'DSP48E': '0'}}

# %% [markdown]
# ## Check the reports

# %%
hls4ml.report.read_vivado_report('hls4ml/f_8_bits/')
# Out:
# Found 1 solution(s) in hls4ml/f_8_bits//myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vitis HLS Report for 'myproject'
# ================================================================
# * Date:           Sat Jul 19 16:21:59 2025
#
# * Version:        2023.2 (Build 4023990 on Oct 11 2023)
# * Project:        myproject_prj
# * Solution:       solution1 (Vivado IP Flow Target)
# * Product family: virtexuplus
# * Target device:  xcu250-figd2104-2L-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  |  5.00 ns|  3.302 ns|     1.35 ns|
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+------+------+----------+
#     |  Latency (cycles) |   Latency (absolute)  |   Interval  | Pipeline |
#     |   min   |   max   |    min    |    max    |  min |  max |   Type   |
#     +---------+---------+-----------+-----------+------+------+----------+
#     |     4335|     4335|  21.675 us|  21.675 us|  4330|  4330|  dataflow|
#     +---------+---------+-----------+-----------+------+------+----------+
#
#     + Detail:
#         * Instance:
#         +-----------------------------------------------------------------------+----------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+---------+
#         |                                                                       |                                                                      |  Latency (cycles) |   Latency (absolute)  |   Interval  | Pipeline|
#         |                                Instance                               |                                Module                                |   min   |   max   |    min    |    max    |  min |  max |   Type  |
#         +-----------------------------------------------------------------------+----------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+---------+
#         |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_8_4_5_3_0_1u_config7_U0  |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_8_4_5_3_0_1u_config7_s  |     2171|     2171|  10.855 us|  10.855 us|  2171|  2171|       no|
#         |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_19_11_5_3_0_8u_config2_U0  |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_19_11_5_3_0_8u_config2_s  |     4329|     4329|  21.645 us|  21.645 us|  4329|  4329|       no|
#         |relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config3_U0     |relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config3_s     |     2162|     2162|  10.810 us|  10.810 us|  2162|  2162|       no|
#         |global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_8u_config4_U0       |global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_8u_config4_s       |     2164|     2164|  10.820 us|  10.820 us|  2164|  2164|       no|
#         |dense_array_ap_fixed_8u_array_ap_fixed_20_12_5_3_0_1u_config5_U0       |dense_array_ap_fixed_8u_array_ap_fixed_20_12_5_3_0_1u_config5_s       |        3|        3|  15.000 ns|  15.000 ns|     3|     3|       no|
#         |sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_U0           |sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_s           |        3|        3|  15.000 ns|  15.000 ns|     3|     3|       no|
#         +-----------------------------------------------------------------------+----------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+---------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +---------------------+---------+-------+---------+---------+------+
# |         Name        | BRAM_18K|  DSP  |    FF   |   LUT   | URAM |
# +---------------------+---------+-------+---------+---------+------+
# |DSP                  |        -|      -|        -|        -|     -|
# |Expression           |        -|      -|        0|        2|     -|
# |FIFO                 |       11|      -|      950|      573|     -|
# |Instance             |        1|      0|      623|     3027|     -|
# |Memory               |        -|      -|        -|        -|     -|
# |Multiplexer          |        -|      -|        -|        -|     -|
# |Register             |        -|      -|        -|        -|     -|
# +---------------------+---------+-------+---------+---------+------+
# |Total                |       12|      0|     1573|     3602|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available SLR        |     1344|   3072|   864000|   432000|   320|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization SLR (%)  |       ~0|      0|       ~0|       ~0|     0|
# +---------------------+---------+-------+---------+---------+------+
# |Available            |     5376|  12288|  3456000|  1728000|  1280|
# +---------------------+---------+-------+---------+---------+------+
# |Utilization (%)      |       ~0|      0|       ~0|       ~0|     0|
# +---------------------+---------+-------+---------+---------+------+
#
# + Detail:
#     * Instance:
#     +-----------------------------------------------------------------------+----------------------------------------------------------------------+---------+----+-----+------+-----+
#     |                                Instance                               |                                Module                                | BRAM_18K| DSP|  FF |  LUT | URAM|
#     +-----------------------------------------------------------------------+----------------------------------------------------------------------+---------+----+-----+------+-----+
#     |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_19_11_5_3_0_8u_config2_U0  |conv_1d_cl_array_ap_fixed_1u_array_ap_fixed_19_11_5_3_0_8u_config2_s  |        0|   0|  305|  1275|    0|
#     |dense_array_ap_fixed_8u_array_ap_fixed_20_12_5_3_0_1u_config5_U0       |dense_array_ap_fixed_8u_array_ap_fixed_20_12_5_3_0_1u_config5_s       |        0|   0|  134|   464|    0|
#     |global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_8u_config4_U0       |global_pooling1d_cl_array_array_ap_fixed_8_4_5_3_0_8u_config4_s       |        0|   0|   85|   401|    0|
#     |relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config3_U0     |relu_array_ap_fixed_8u_array_ap_fixed_8_4_5_3_0_8u_relu_config3_s     |        0|   0|   16|   381|    0|
#     |sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_U0           |sigmoid_array_array_ap_fixed_8_4_5_3_0_1u_sigmoid_config6_s           |        1|   0|   45|   231|    0|
#     |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_8_4_5_3_0_1u_config7_U0  |zeropad1d_cl_array_ap_fixed_1u_array_ap_fixed_8_4_5_3_0_1u_config7_s  |        0|   0|   38|   275|    0|
#     +-----------------------------------------------------------------------+----------------------------------------------------------------------+---------+----+-----+------+-----+
#     |Total                                                                  |                                                                      |        1|   0|  623|  3027|    0|
#     +-----------------------------------------------------------------------+----------------------------------------------------------------------+---------+----+-----+------+-----+
#
#     * DSP:
#     N/A
#
#     * Memory:
#     N/A
#
#     * FIFO:
#     +--------------+---------+-----+----+-----+------+-----+---------+
#     |     Name     | BRAM_18K|  FF | LUT| URAM| Depth| Bits| Size:D*B|
#     +--------------+---------+-----+----+-----+------+-----+---------+
#     |layer2_out_U  |        8|  543|   0|    -|  2160|  152|   328320|
#     |layer3_out_U  |        2|  159|   0|    -|  2160|   64|   138240|
#     |layer4_out_U  |        0|  133|   0|    -|     1|   64|       64|
#     |layer5_out_U  |        0|   68|   0|    -|     1|   20|       20|
#     |layer7_out_U  |        1|   47|   0|    -|  2163|    8|    17304|
#     +--------------+---------+-----+----+-----+------+-----+---------+
#     |Total         |       11|  950|   0|    0|  6485|  308|   483948|
#     +--------------+---------+-----+----+-----+------+-----+---------+
#
#     * Expression:
#     +--------------+----------+----+---+----+------------+------------+
#     | Variable Name| Operation| DSP| FF| LUT| Bitwidth P0| Bitwidth P1|
#     +--------------+----------+----+---+----+------------+------------+
#     |ap_idle       |       and|   0|  0|   2|           1|           1|
#     +--------------+----------+----+---+----+------------+------------+
#     |Total         |          |   0|  0|   2|           1|           1|
#     +--------------+----------+----+---+----+------------+------------+
#
#     * Multiplexer:
#     N/A
#
#     * Register:
#     N/A
#
#
#
# ================================================================
# == Interface
# ================================================================
# * Summary:
# +---------------------+-----+-----+------------+--------------+--------------+
# |      RTL Ports      | Dir | Bits|  Protocol  | Source Object|    C Type    |
# +---------------------+-----+-----+------------+--------------+--------------+
# |conv1d_input_TDATA   |   in|    8|        axis|  conv1d_input|       pointer|
# |conv1d_input_TVALID  |   in|    1|        axis|  conv1d_input|       pointer|
# |conv1d_input_TREADY  |  out|    1|        axis|  conv1d_input|       pointer|
# |layer6_out_TDATA     |  out|    8|        axis|    layer6_out|       pointer|
# |layer6_out_TVALID    |  out|    1|        axis|    layer6_out|       pointer|
# |layer6_out_TREADY    |   in|    1|        axis|    layer6_out|       pointer|
# |ap_clk               |   in|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_rst_n             |   in|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_start             |   in|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_done              |  out|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_ready             |  out|    1|  ap_ctrl_hs|     myproject|  return value|
# |ap_idle              |  out|    1|  ap_ctrl_hs|     myproject|  return value|
# +---------------------+-----+-----+------------+--------------+--------------+
#
# Co-simulation report not found.
